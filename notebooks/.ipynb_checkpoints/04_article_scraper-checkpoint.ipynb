# %% [markdown]
# # 04: Full-Text Article Scraper
# **Goal**: Extract full article content for records missing descriptions
#
# **Strategy**:
# 1. Test trafilatura on sample articles
# 2. Fetch articles needing scraping from Supabase
# 3. Extract content in batches with error handling
# 4. Update database with extracted content
# 5. Generate quality report
#
# **Target**: 82 articles (50 archive + 32 RSS without descriptions)

# %% [markdown]
# ## Phase 1: Setup & Library Testing

# %%
# Install required libraries (run once)
# !pip install trafilatura supabase python-dotenv requests

import trafilatura
from supabase import create_client, Client
import requests
import pandas as pd
from datetime import datetime
import time
from typing import List, Dict, Tuple
import json

print("✅ Libraries imported successfully")
print(f"Trafilatura version: {trafilatura.__version__}")
# Out:
# ✅ Libraries imported successfully
# Trafilatura version: 2.0.0

# %%
# ============================================
# SUPABASE CREDENTIALS - REPLACE THESE
# ============================================
SUPABASE_URL = "https://lgnhjzlbezpczlobeevu.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImxnbmhqemxiZXpwY3psb2JlZXZ1Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTgyMDgzNjcsImV4cCI6MjA3Mzc4NDM2N30.O5Yt0dOyYq326ESo0LBL7lGj4k8zwpuodJfTtGwrPek"
# ============================================

# Initialize Supabase client
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

print("✅ Supabase client initialized!")
print(f"Connected to: {SUPABASE_URL}")
# Out:
# ✅ Supabase client initialized!
# Connected to: https://lgnhjzlbezpczlobeevu.supabase.co

# %%
# Test trafilatura on a single article
TEST_URL = "https://www.thehindu.com/news/national/tamil-nadu/encroachments-demolished-to-complete-new-bridge-across-kamadalam-river-near-arani/article70102100.ece"

print(f"🧪 Testing extraction on: {TEST_URL}\n")
print("="*60)

try:
    # Download HTML
    downloaded = trafilatura.fetch_url(TEST_URL)
    
    if downloaded:
        # Extract content
        content = trafilatura.extract(downloaded, include_comments=False, include_tables=False)
        
        if content:
            print("✅ Extraction Successful!\n")
            print(f"Content Length: {len(content)} characters")
            print(f"Word Count: ~{len(content.split())} words\n")
            print("First 500 characters:")
            print("-"*60)
            print(content[:500])
            print("-"*60)
        else:
            print("⚠️ Extraction returned empty content")
    else:
        print("❌ Failed to download page")
        
except Exception as e:
    print(f"❌ Error: {e}")

print("\n💡 If extraction worked, proceed. If failed, we'll need a custom scraper.")
# Out:
# 🧪 Testing extraction on: https://www.thehindu.com/news/national/tamil-nadu/encroachments-demolished-to-complete-new-bridge-across-kamadalam-river-near-arani/article70102100.ece
#
# ============================================================
# ✅ Extraction Successful!
#
# Content Length: 2234 characters
# Word Count: ~374 words
#
# First 500 characters:
# ------------------------------------------------------------
# The State Highways Department demolished encroachments on Arcot - Villupuram Main Road (SH-4) near old bus terminus in Arani town in Tiruvannamalai to lay bitumen approach roads as part of completion of the two-lane high level bridge across Kamadalam Naganathi river.
# Officials of State Highways, which is constructing the bridge, said that most of the encroachments are houses and petty shops, which were built more than two decades ago. Encroached land near the bus terminus belongs to State Highwa
# ------------------------------------------------------------
#
# 💡 If extraction worked, proceed. If failed, we'll need a custom scraper.

# %% [markdown]
# ## Phase 2: Fetch Target Articles from Database

# %%
# Fetch all articles needing full-text scraping
print("📥 Fetching articles that need scraping...\n")

result = supabase.table('news_cleaned') \
    .select('id, title, link, source, category') \
    .eq('needs_full_scrape', True) \
    .execute()

articles_to_scrape = result.data

print("="*60)
print("📊 ARTICLES NEEDING SCRAPING")
print("="*60)
print(f"Total: {len(articles_to_scrape)} articles\n")

# Breakdown by source
df_scrape = pd.DataFrame(articles_to_scrape)
source_counts = df_scrape['source'].value_counts()

print("By Source:")
for source, count in source_counts.items():
    print(f"  {source}: {count}")

# Category breakdown
print("\nBy Category:")
category_counts = df_scrape['category'].value_counts()
for cat, count in category_counts.head(5).items():
    print(f"  {cat}: {count}")

print("\n💡 Recommendation: Start with 20 articles (10 archive + 10 RSS) for testing")
# Out:
# 📥 Fetching articles that need scraping...
#
# ============================================================
# 📊 ARTICLES NEEDING SCRAPING
# ============================================================
# Total: 527 articles
#
# By Source:
#   The Hindu - Archive: 527
#
# By Category:
#   Tamil Nadu: 155
#   Chennai: 135
#   Madurai: 128
#   Coimbatore: 109
#
# 💡 Recommendation: Start with 20 articles (10 archive + 10 RSS) for testing

# %%
# Select test batch: 10 archive + 10 RSS
archive_articles = [a for a in articles_to_scrape if 'Archive' in a['source']][:10]
rss_articles = [a for a in articles_to_scrape if 'RSS' in a['source']][:10]

test_batch = archive_articles + rss_articles

print("🎯 TEST BATCH SELECTED")
print("="*60)
print(f"Archive articles: {len(archive_articles)}")
print(f"RSS articles: {len(rss_articles)}")
print(f"Total test batch: {len(test_batch)}\n")

print("Sample articles:")
for i, article in enumerate(test_batch[:3], 1):
    print(f"\n{i}. [{article['source']}]")
    print(f"   {article['title'][:60]}...")
    print(f"   {article['link'][:70]}...")
# Out:
# 🎯 TEST BATCH SELECTED
# ============================================================
# Archive articles: 10
# RSS articles: 0
# Total test batch: 10
#
# Sample articles:
#
# 1. [The Hindu - Archive]
#    IIT Madras-incubated Muse Wearables partners with NPCI to la...
#    https://www.thehindu.com/news/cities/chennai/iit-madras-incubated-muse...
#
# 2. [The Hindu - Archive]
#    Foxconn leadership meets CM Stalin, to invest ₹15,000 crore ...
#    https://www.thehindu.com/news/national/tamil-nadu/foxconn-leadership-m...
#
# 3. [The Hindu - Archive]
#    Tamil Nadu issues G.O. to cancel 11th standard public exam f...
#    https://www.thehindu.com/news/national/tamil-nadu/tamil-nadu-issues-go...

# %% [markdown]
# ## Phase 3: Content Extraction Pipeline

# %%
def extract_article_content(url: str, max_retries: int = 3, timeout: int = 10) -> Dict:
    """
    Extract full article content from URL using trafilatura
    
    Returns:
        Dict with keys: success, content, error, word_count
    """
    result = {
        'success': False,
        'content': None,
        'error': None,
        'word_count': 0
    }
    
    for attempt in range(max_retries):
        try:
            # Download HTML
            downloaded = trafilatura.fetch_url(url)
            
            if not downloaded:
                result['error'] = 'Failed to download page'
                continue
            
            # Extract content
            content = trafilatura.extract(
                downloaded,
                include_comments=False,
                include_tables=False,
                no_fallback=False  # Try harder to extract content
            )
            
            if content and len(content.strip()) > 100:  # Min 100 chars
                result['success'] = True
                result['content'] = content.strip()
                result['word_count'] = len(content.split())
                return result
            else:
                result['error'] = 'Empty or too short content'
                
        except requests.exceptions.Timeout:
            result['error'] = f'Timeout (attempt {attempt + 1}/{max_retries})'
        except requests.exceptions.RequestException as e:
            result['error'] = f'Network error: {str(e)[:50]}'
            break  # Don't retry network errors
        except Exception as e:
            result['error'] = f'Extraction error: {str(e)[:50]}'
            break
        
        if attempt < max_retries - 1:
            time.sleep(2)  # Wait before retry
    
    return result

print("✅ Extraction function defined")
print("Features: 3 retries, 10s timeout, min 100 chars validation")
# Out:
# ✅ Extraction function defined
# Features: 3 retries, 10s timeout, min 100 chars validation

# %%
def scrape_articles_batch(articles: List[Dict], rate_limit: float = 2.5) -> List[Dict]:
    """
    Scrape multiple articles with progress tracking
    
    Args:
        articles: List of dicts with 'id', 'link', 'title'
        rate_limit: Seconds to wait between requests
    
    Returns:
        List of dicts with scraping results
    """
    results = []
    total = len(articles)
    
    print(f"🚀 Starting batch scraping: {total} articles")
    print(f"⏱️  Rate limit: {rate_limit}s between requests\n")
    print("="*60)
    
    for i, article in enumerate(articles, 1):
        print(f"\n[{i}/{total}] Scraping: {article['title'][:50]}...")
        print(f"URL: {article['link'][:60]}...")
        
        # Extract content
        extraction = extract_article_content(article['link'])
        
        # Store result
        result = {
            'id': article['id'],
            'title': article['title'],
            'link': article['link'],
            'source': article['source'],
            'success': extraction['success'],
            'content': extraction['content'],
            'word_count': extraction['word_count'],
            'error': extraction['error']
        }
        results.append(result)
        
        # Progress indicator
        if extraction['success']:
            print(f"✅ Success! Extracted {extraction['word_count']} words")
        else:
            print(f"❌ Failed: {extraction['error']}")
        
        # Rate limiting (skip on last article)
        if i < total:
            time.sleep(rate_limit)
    
    print("\n" + "="*60)
    print("✅ Batch scraping complete!")
    
    return results

print("✅ Batch scraper function defined")
# Out:
# ✅ Batch scraper function defined

# %%
# Run scraping on test batch
print(f"⚠️  About to scrape {len(test_batch)} articles")
print(f"Estimated time: ~{len(test_batch) * 2.5 / 60:.1f} minutes\n")

# Start scraping
scraping_results = scrape_articles_batch(test_batch, rate_limit=2.5)
# Out:
# ⚠️  About to scrape 10 articles
# Estimated time: ~0.4 minutes
#
# 🚀 Starting batch scraping: 10 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/10] Scraping: IIT Madras-incubated Muse Wearables partners with ...
# URL: https://www.thehindu.com/news/cities/chennai/iit-madras-incu...
# ✅ Success! Extracted 445 words
#
# [2/10] Scraping: Foxconn leadership meets CM Stalin, to invest ₹15,...
# URL: https://www.thehindu.com/news/national/tamil-nadu/foxconn-le...
# ✅ Success! Extracted 454 words
#
# [3/10] Scraping: Tamil Nadu issues G.O. to cancel 11th standard pub...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tamil-nadu...
# ✅ Success! Extracted 224 words
#
# [4/10] Scraping: Supreme Court orders CBI probe into Karur stampede...
# URL: https://www.thehindu.com/news/national/tamil-nadu/supreme-co...
# ✅ Success! Extracted 1131 words
#
# [5/10] Scraping: Cough syrup deaths: ED conducts searches at seven ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/ed-conduct...
# ✅ Success! Extracted 296 words
#
# [6/10] Scraping: SC hearing on Karur stampede updates: SC transfers...
# URL: https://www.thehindu.com/news/national/tamil-nadu/supreme-co...
# ✅ Success! Extracted 217 words
#
# [7/10] Scraping: Capturing the tough journey and phenomenal success...
# URL: https://www.thehindu.com/news/cities/chennai/capturing-the-t...
# ✅ Success! Extracted 684 words
#
# [8/10] Scraping: AAI mulls introducing dedicated valet parking serv...
# URL: https://www.thehindu.com/news/cities/chennai/aai-mulls-intro...
# ✅ Success! Extracted 325 words
#
# [9/10] Scraping: Consumer body objects to amendment allowing advt. ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/consumer-bod...
# ✅ Success! Extracted 301 words
#
# [10/10] Scraping: Book on efforts of Mumbai police to combat underwo...
# URL: https://www.thehindu.com/news/cities/chennai/book-on-efforts...
# ✅ Success! Extracted 274 words
#
# ============================================================
# ✅ Batch scraping complete!

# %%
# Analyze scraping results
df_results = pd.DataFrame(scraping_results)

success_count = df_results['success'].sum()
failure_count = len(df_results) - success_count
success_rate = (success_count / len(df_results)) * 100

print("="*60)
print("📊 SCRAPING RESULTS SUMMARY")
print("="*60)
print(f"Total Attempted: {len(df_results)}")
print(f"Successful: {success_count} ({success_rate:.1f}%)")
print(f"Failed: {failure_count} ({100-success_rate:.1f}%)\n")

# Success by source
print("Success Rate by Source:")
source_success = df_results.groupby('source')['success'].agg(['sum', 'count'])
source_success['rate'] = (source_success['sum'] / source_success['count'] * 100).round(1)
for source, row in source_success.iterrows():
    print(f"  {source}: {row['sum']}/{row['count']} ({row['rate']}%)")

# Word count statistics (for successful extractions)
successful_df = df_results[df_results['success'] == True]
if len(successful_df) > 0:
    print(f"\nWord Count Statistics:")
    print(f"  Average: {successful_df['word_count'].mean():.0f} words")
    print(f"  Median: {successful_df['word_count'].median():.0f} words")
    print(f"  Min: {successful_df['word_count'].min()} words")
    print(f"  Max: {successful_df['word_count'].max()} words")

# Error breakdown
if failure_count > 0:
    print(f"\nError Breakdown:")
    error_counts = df_results[df_results['success'] == False]['error'].value_counts()
    for error, count in error_counts.items():
        print(f"  {error}: {count}")
# Out:
# ============================================================
# 📊 SCRAPING RESULTS SUMMARY
# ============================================================
# Total Attempted: 10
# Successful: 10 (100.0%)
# Failed: 0 (0.0%)
#
# Success Rate by Source:
#   The Hindu - Archive: 10.0/10.0 (100.0%)
#
# Word Count Statistics:
#   Average: 435 words
#   Median: 313 words
#   Min: 217 words
#   Max: 1131 words

# %%
# Inspect sample extractions
print("="*60)
print("📰 SAMPLE EXTRACTED CONTENT")
print("="*60)

successful_samples = df_results[df_results['success'] == True].head(3)

for i, row in successful_samples.iterrows():
    print(f"\n{i+1}. {row['title'][:60]}...")
    print(f"   Source: {row['source']}")
    print(f"   Words: {row['word_count']}")
    print(f"   Content Preview:")
    print("-"*60)
    print(row['content'][:300] + "...")
    print("-"*60)
# Out:
# ============================================================
# 📰 SAMPLE EXTRACTED CONTENT
# ============================================================
#
# 1. IIT Madras-incubated Muse Wearables partners with NPCI to la...
#    Source: The Hindu - Archive
#    Words: 445
#    Content Preview:
# ------------------------------------------------------------
# Muse Wearables, which started its journey from IIT-Madras, has partnered with the National Payments Corporation of India (NPCI) to launch India’s first wearable payments ecosystem, powered by Muse Wallet and NPCI’s trusted RuPay network.
# The new ecosystem allows users to make instant, secure payment...
# ------------------------------------------------------------
#
# 2. Foxconn leadership meets CM Stalin, to invest ₹15,000 crore ...
#    Source: The Hindu - Archive
#    Words: 454
#    Content Preview:
# ------------------------------------------------------------
# A delegation from Foxconn, a multinational electronics manufacturer, met Tamil Nadu Chief Minister M.K. Stalin on Monday (October 13, 2025) and announced a ₹15,000-crore investment in the State, 14,000 engineering jobs, and a dedicated Foxconn Desk at Guidance, the State’s nodal agency for investmen...
# ------------------------------------------------------------
#
# 3. Tamil Nadu issues G.O. to cancel 11th standard public exam f...
#    Source: The Hindu - Archive
#    Words: 224
#    Content Preview:
# ------------------------------------------------------------
# In a step towards implementing the State Education Policy, the Tamil Nadu government has issued a Government Order (G.O.) to cancel the 11th standard public exams from this academic year.
# According to the G.O., starting from the academic year 2025-2026, students in the 11th standard will take their ...
# ------------------------------------------------------------

# %% [markdown]
# ## Phase 4: Update Database

# %%
def update_articles_in_db(results: List[Dict]) -> Dict:
    """
    Update Supabase with scraped content
    
    Returns:
        Dict with update statistics
    """
    updated = 0
    failed_updates = 0
    
    print("🔄 Updating database...\n")
    
    for result in results:
        if result['success']:
            try:
                # Update record
                supabase.table('news_cleaned').update({
                    'content_full': result['content'],
                    'needs_full_scrape': False
                }).eq('id', result['id']).execute()
                
                updated += 1
                print(f"✅ Updated: {result['title'][:50]}...")
                
            except Exception as e:
                failed_updates += 1
                print(f"❌ Failed to update {result['id']}: {e}")
    
    return {
        'updated': updated,
        'failed': failed_updates
    }

print("✅ Update function defined")
# Out:
# ✅ Update function defined

# %%
# Update database with successful extractions
print(f"⚠️  About to update {success_count} records in database\n")
print("="*60)

update_stats = update_articles_in_db(scraping_results)

print("\n" + "="*60)
print("📊 UPDATE SUMMARY")
print("="*60)
print(f"Successfully Updated: {update_stats['updated']}")
print(f"Failed Updates: {update_stats['failed']}")
# Out:
# ⚠️  About to update 10 records in database
#
# ============================================================
# 🔄 Updating database...
#
# ✅ Updated: IIT Madras-incubated Muse Wearables partners with ...
# ✅ Updated: Foxconn leadership meets CM Stalin, to invest ₹15,...
# ✅ Updated: Tamil Nadu issues G.O. to cancel 11th standard pub...
# ✅ Updated: Supreme Court orders CBI probe into Karur stampede...
# ✅ Updated: Cough syrup deaths: ED conducts searches at seven ...
# ✅ Updated: SC hearing on Karur stampede updates: SC transfers...
# ✅ Updated: Capturing the tough journey and phenomenal success...
# ✅ Updated: AAI mulls introducing dedicated valet parking serv...
# ✅ Updated: Consumer body objects to amendment allowing advt. ...
# ✅ Updated: Book on efforts of Mumbai police to combat underwo...
#
# ============================================================
# 📊 UPDATE SUMMARY
# ============================================================
# Successfully Updated: 10
# Failed Updates: 0

# %%
# Verify updates in database
print("🔍 Verifying database updates...\n")

# Check total articles still needing scraping
remaining = supabase.table('news_cleaned').select('*', count='exact').eq('needs_full_scrape', True).execute()

# Check articles with content
with_content = supabase.table('news_cleaned').select('*', count='exact').not_.is_('content_full', 'null').execute()

print("="*60)
print("📊 DATABASE STATUS")
print("="*60)
print(f"Articles still needing scraping: {remaining.count}")
print(f"Articles with full content: {with_content.count}")
print(f"\n✅ Reduction: {82 - remaining.count} articles scraped from original 82")
# Out:
# 🔍 Verifying database updates...
#
# ============================================================
# 📊 DATABASE STATUS
# ============================================================
# Articles still needing scraping: 517
# Articles with full content: 755
#
# ✅ Reduction: -435 articles scraped from original 82

# %% [markdown]
# ## Phase 5: Export Failed Articles & Full Batch Processing

# %%
# Export failed articles for investigation
failed_df = df_results[df_results['success'] == False][['title', 'link', 'source', 'error']]

if len(failed_df) > 0:
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    filename = f"../data/raw/failed_scrapes_{timestamp}.csv"
    failed_df.to_csv(filename, index=False)
    print(f"📁 Exported {len(failed_df)} failed articles to: {filename}")
else:
    print("✅ No failed articles to export!")
# Out:
# ✅ No failed articles to export!

# %%
# OPTIONAL: Process all remaining articles
# ⚠️  Uncomment and run this cell ONLY after validating test batch results

print("⚠️  PROCESSING ALL REMAINING ARTICLES")
print(f"This will scrape ~{remaining.count} articles")
print(f"Estimated time: ~{remaining.count * 2.5 / 60:.1f} minutes\n")

# Fetch all remaining articles
remaining_articles = supabase.table('news_cleaned') \
    .select('id, title, link, source, category') \
    .eq('needs_full_scrape', True) \
    .execute()

# Scrape in batches of 20
batch_size = 20
all_results = []

for i in range(0, len(remaining_articles.data), batch_size):
    batch = remaining_articles.data[i:i+batch_size]
    print(f"\n🔄 Processing batch {i//batch_size + 1}...")
    batch_results = scrape_articles_batch(batch)
    update_articles_in_db(batch_results)
    all_results.extend(batch_results)
    time.sleep(5)  # Pause between batches

print("\n✅ All articles processed!")

# print("💡 Uncomment this cell to process all remaining articles after test validation")
# Out:
# ⚠️  PROCESSING ALL REMAINING ARTICLES
# This will scrape ~517 articles
# Estimated time: ~21.5 minutes
#
#
# 🔄 Processing batch 1...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Chennai’s retail market witnesses 8% year-on-year ...
# URL: https://www.thehindu.com/news/cities/chennai/chennais-retail...
# ✅ Success! Extracted 330 words
#
# [2/20] Scraping: Residents, activists raise questions over renaming...
# URL: https://www.thehindu.com/news/cities/chennai/residents-activ...
# ✅ Success! Extracted 379 words
#
# [3/20] Scraping: State lists out members of town vending committees...
# URL: https://www.thehindu.com/news/cities/chennai/state-lists-out...
# ✅ Success! Extracted 182 words
#
# [4/20] Scraping: Youth swept by a huge wave in Elliots beach...
# URL: https://www.thehindu.com/news/cities/chennai/youth-swept-by-...
# ✅ Success! Extracted 110 words
#
# [5/20] Scraping: School Education Minister speaks on Dravidian Mode...
# URL: https://www.thehindu.com/news/cities/chennai/school-educatio...
# ✅ Success! Extracted 172 words
#
# [6/20] Scraping: Walkathon to create awareness on Down Syndrome hel...
# URL: https://www.thehindu.com/news/national/tamil-nadu/walkathon-...
# ✅ Success! Extracted 96 words
#
# [7/20] Scraping: T.N. Ministers review construction of hostels in C...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tn-ministe...
# ✅ Success! Extracted 130 words
#
# [8/20] Scraping: Drill on northeast monsoon preparedness held in Dh...
# URL: https://www.thehindu.com/news/cities/Coimbatore/drill-on-nor...
# ✅ Success! Extracted 144 words
#
# [9/20] Scraping: Two die in accident in Namakkal...
# URL: https://www.thehindu.com/news/cities/Coimbatore/two-die-in-a...
# ✅ Success! Extracted 125 words
#
# [10/20] Scraping: ‘The Brahmastra Unleashed’ launched in Chennai: Ex...
# URL: https://www.thehindu.com/news/cities/chennai/the-brahmastra-...
# ✅ Success! Extracted 294 words
#
# [11/20] Scraping: Metrowater ramps up monsoon preparedness to tackle...
# URL: https://www.thehindu.com/news/cities/chennai/metrowater-ramp...
# ✅ Success! Extracted 428 words
#
# [12/20] Scraping: Complaints of faulty street lights, poor garbage c...
# URL: https://www.thehindu.com/news/cities/chennai/complaints-of-f...
# ✅ Success! Extracted 236 words
#
# [13/20] Scraping: CM Stalin to inaugurate two mega food parks in T.N...
# URL: https://www.thehindu.com/news/national/tamil-nadu/cm-stalin-...
# ✅ Success! Extracted 178 words
#
# [14/20] Scraping: Temple priest found murdered...
# URL: https://www.thehindu.com/news/cities/Madurai/temple-priest-f...
# ✅ Success! Extracted 111 words
#
# [15/20] Scraping: T.N. Minister inaugurates Fire and Rescue station ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tn-ministe...
# ✅ Success! Extracted 360 words
#
# [16/20] Scraping: SIT detains two persons over kidney sale racket in...
# URL: https://www.thehindu.com/news/cities/Coimbatore/sit-detains-...
# ✅ Success! Extracted 190 words
#
# [17/20] Scraping: CSIR- SERC develops technology to reduce construct...
# URL: https://www.thehindu.com/news/national/tamil-nadu/csir-serc-...
# ✅ Success! Extracted 297 words
#
# [18/20] Scraping: Karur stampede case: DMK sees bid to mislead Supre...
# URL: https://www.thehindu.com/news/national/tamil-nadu/dmk-allege...
# ✅ Success! Extracted 243 words
#
# [19/20] Scraping: Countdown for DMK government’s time in office has ...
# URL: https://www.thehindu.com/news/cities/Madurai/countdown-for-d...
# ✅ Success! Extracted 435 words
#
# [20/20] Scraping: DMK arrogant about winning Assembly polls by bribi...
# URL: https://www.thehindu.com/news/cities/Madurai/dmk-arrogant-ab...
# ✅ Success! Extracted 319 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Chennai’s retail market witnesses 8% year-on-year ...
# ✅ Updated: Residents, activists raise questions over renaming...
# ✅ Updated: State lists out members of town vending committees...
# ✅ Updated: Youth swept by a huge wave in Elliots beach...
# ✅ Updated: School Education Minister speaks on Dravidian Mode...
# ✅ Updated: Walkathon to create awareness on Down Syndrome hel...
# ✅ Updated: T.N. Ministers review construction of hostels in C...
# ✅ Updated: Drill on northeast monsoon preparedness held in Dh...
# ✅ Updated: Two die in accident in Namakkal...
# ✅ Updated: ‘The Brahmastra Unleashed’ launched in Chennai: Ex...
# ✅ Updated: Metrowater ramps up monsoon preparedness to tackle...
# ✅ Updated: Complaints of faulty street lights, poor garbage c...
# ✅ Updated: CM Stalin to inaugurate two mega food parks in T.N...
# ✅ Updated: Temple priest found murdered...
# ✅ Updated: T.N. Minister inaugurates Fire and Rescue station ...
# ✅ Updated: SIT detains two persons over kidney sale racket in...
# ✅ Updated: CSIR- SERC develops technology to reduce construct...
# ✅ Updated: Karur stampede case: DMK sees bid to mislead Supre...
# ✅ Updated: Countdown for DMK government’s time in office has ...
# ✅ Updated: DMK arrogant about winning Assembly polls by bribi...
#
# 🔄 Processing batch 2...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: CPI(M), Congress likely to seek more seats in Tami...
# URL: https://www.thehindu.com/news/national/tamil-nadu/cpim-will-...
# ✅ Success! Extracted 577 words
#
# [2/20] Scraping: Residents urge Coimbatore Corporation to immediate...
# URL: https://www.thehindu.com/news/cities/Coimbatore/residents-ur...
# ✅ Success! Extracted 335 words
#
# [3/20] Scraping: Helpline assistance should be available in every d...
# URL: https://www.thehindu.com/news/cities/Madurai/helpline-assist...
# ✅ Success! Extracted 401 words
#
# [4/20] Scraping: Will not discuss alliance expectations in public: ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/will-not-d...
# ✅ Success! Extracted 342 words
#
# [5/20] Scraping: Petrol bombs hurled near Thatchanallur police stat...
# URL: https://www.thehindu.com/news/cities/Madurai/petrol-bombs-hu...
# ✅ Success! Extracted 150 words
#
# [6/20] Scraping: Tamil Nadu medical graduate wins second prize at B...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tamil-nadu...
# ✅ Success! Extracted 113 words
#
# [7/20] Scraping: Chennai’s retail market sees 8% YoY growth in Q3 2...
# URL: https://www.thehindu.com/news/national/tamil-nadu/chennais-r...
# ✅ Success! Extracted 328 words
#
# [8/20] Scraping: Madurai reader’s mail...
# URL: https://www.thehindu.com/news/cities/Madurai/madurai-readers...
# ✅ Success! Extracted 533 words
#
# [9/20] Scraping: Kanniyakumari police intensify action against unde...
# URL: https://www.thehindu.com/news/cities/Madurai/kanniyakumari-p...
# ✅ Success! Extracted 311 words
#
# [10/20] Scraping: Four killed in a multiple-vehicle collision in Kri...
# URL: https://www.thehindu.com/news/cities/Coimbatore/four-killed-...
# ✅ Success! Extracted 236 words
#
# [11/20] Scraping: Preliminary findings from Thirumalapuram excavatio...
# URL: https://www.thehindu.com/news/national/tamil-nadu/preliminar...
# ✅ Success! Extracted 391 words
#
# [12/20] Scraping: Tirunelveli reader’s mail...
# URL: https://www.thehindu.com/news/cities/Madurai/tirunelveli-rea...
# ✅ Success! Extracted 243 words
#
# [13/20] Scraping: Dindigul reader’s mail...
# URL: https://www.thehindu.com/news/cities/Madurai/dindigul-reader...
# ✅ Success! Extracted 138 words
#
# [14/20] Scraping: Twenty-one low-floor buses with facilities for dif...
# URL: https://www.thehindu.com/news/cities/Madurai/twenty-one-low-...
# ✅ Success! Extracted 248 words
#
# [15/20] Scraping: Ministers from Punjab call on T.N. CM Stalin...
# URL: https://www.thehindu.com/news/national/tamil-nadu/ministers-...
# ✅ Success! Extracted 117 words
#
# [16/20] Scraping: Earmark pathway for pedestrians to walk safely on ...
# URL: https://www.thehindu.com/news/cities/Madurai/earmark-pathway...
# ✅ Success! Extracted 284 words
#
# [17/20] Scraping: Kumki Chinnathambi replaces Muthu, Narasimhan as o...
# URL: https://www.thehindu.com/news/cities/Coimbatore/kumki-chinna...
# ✅ Success! Extracted 230 words
#
# [18/20] Scraping: Man killed in dispute over fishing at Perumpallam ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/man-killed-i...
# ✅ Success! Extracted 196 words
#
# [19/20] Scraping: Man, son get life term for murder...
# URL: https://www.thehindu.com/news/cities/Madurai/man-son-get-lif...
# ✅ Success! Extracted 112 words
#
# [20/20] Scraping: Six ATM robbery accused get jail term in Namakkal ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/six-atm-robb...
# ✅ Success! Extracted 313 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: CPI(M), Congress likely to seek more seats in Tami...
# ✅ Updated: Residents urge Coimbatore Corporation to immediate...
# ✅ Updated: Helpline assistance should be available in every d...
# ✅ Updated: Will not discuss alliance expectations in public: ...
# ✅ Updated: Petrol bombs hurled near Thatchanallur police stat...
# ✅ Updated: Tamil Nadu medical graduate wins second prize at B...
# ✅ Updated: Chennai’s retail market sees 8% YoY growth in Q3 2...
# ✅ Updated: Madurai reader’s mail...
# ✅ Updated: Kanniyakumari police intensify action against unde...
# ✅ Updated: Four killed in a multiple-vehicle collision in Kri...
# ✅ Updated: Preliminary findings from Thirumalapuram excavatio...
# ✅ Updated: Tirunelveli reader’s mail...
# ✅ Updated: Dindigul reader’s mail...
# ✅ Updated: Twenty-one low-floor buses with facilities for dif...
# ✅ Updated: Ministers from Punjab call on T.N. CM Stalin...
# ✅ Updated: Earmark pathway for pedestrians to walk safely on ...
# ✅ Updated: Kumki Chinnathambi replaces Muthu, Narasimhan as o...
# ✅ Updated: Man killed in dispute over fishing at Perumpallam ...
# ✅ Updated: Man, son get life term for murder...
# ✅ Updated: Six ATM robbery accused get jail term in Namakkal ...
#
# 🔄 Processing batch 3...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Mapping of government schools, nearest public libr...
# URL: https://www.thehindu.com/news/cities/Coimbatore/mapping-of-g...
# ✅ Success! Extracted 206 words
#
# [2/20] Scraping: TVK cadre attend AIADMK campaign voluntarily: Edap...
# URL: https://www.thehindu.com/news/cities/Coimbatore/tvk-cadre-at...
# ✅ Success! Extracted 309 words
#
# [3/20] Scraping: Two accused get bail in Armstrong murder case...
# URL: https://www.thehindu.com/news/cities/chennai/two-accused-get...
# ✅ Success! Extracted 223 words
#
# [4/20] Scraping: Two from Kerala held for snatching imitation gold ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/two-from-ker...
# ✅ Success! Extracted 180 words
#
# [5/20] Scraping: Two persons arrested for GST fraud in Chennai...
# URL: https://www.thehindu.com/news/cities/chennai/two-persons-arr...
# ✅ Success! Extracted 303 words
#
# [6/20] Scraping: Online/ Vibe Check/Why Gen Z in Chennai is celebra...
# URL: https://www.thehindu.com/news/cities/chennai/why-gen-z-in-ch...
# ✅ Success! Extracted 580 words
#
# [7/20] Scraping: Kalaignar Magalir Urimai Thittam helps beneficiari...
# URL: https://www.thehindu.com/news/national/tamil-nadu/kalaignar-...
# ✅ Success! Extracted 553 words
#
# [8/20] Scraping: State Planning Commission report on startups calls...
# URL: https://www.thehindu.com/news/national/tamil-nadu/state-plan...
# ✅ Success! Extracted 331 words
#
# [9/20] Scraping: Unorganised workers demand resolution in T.N. Asse...
# URL: https://www.thehindu.com/news/cities/chennai/unorganised-wor...
# ✅ Success! Extracted 325 words
#
# [10/20] Scraping: Minister inspects development works in Royapuram z...
# URL: https://www.thehindu.com/news/cities/chennai/minister-inspec...
# ✅ Success! Extracted 143 words
#
# [11/20] Scraping: Two die in road accident in Singampunari...
# URL: https://www.thehindu.com/news/cities/Madurai/two-die-in-road...
# ✅ Success! Extracted 127 words
#
# [12/20] Scraping: Madras High Court reserves orders on retired IPS o...
# URL: https://www.thehindu.com/news/national/tamil-nadu/madras-hig...
# ✅ Success! Extracted 552 words
#
# [13/20] Scraping: Two held in separate hoax bomb threat cases in Che...
# URL: https://www.thehindu.com/news/cities/chennai/two-held-in-sep...
# ✅ Success! Extracted 349 words
#
# [14/20] Scraping: NCB Southern Region gets new Deputy Director-Gener...
# URL: https://www.thehindu.com/news/national/tamil-nadu/r-sudhakar...
# ✅ Success! Extracted 96 words
#
# [15/20] Scraping: RGGGH performs cross-hand replantation on 28-year-...
# URL: https://www.thehindu.com/news/cities/chennai/rgggh-performs-...
# ✅ Success! Extracted 155 words
#
# [16/20] Scraping: T.N. to get more weather radars; new facility laun...
# URL: https://www.thehindu.com/news/cities/chennai/tn-to-get-more-...
# ✅ Success! Extracted 349 words
#
# [17/20] Scraping: Train services hit on Rameswaram-Ramanathapuram se...
# URL: https://www.thehindu.com/news/cities/Madurai/train-services-...
# ✅ Success! Extracted 241 words
#
# [18/20] Scraping: Dindigul campus connect...
# URL: https://www.thehindu.com/news/cities/Madurai/dindigul-campus...
# ✅ Success! Extracted 620 words
#
# [19/20] Scraping: Tamil Nadu Assembly adopts resolution mourning Kar...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tamil-nadu...
# ✅ Success! Extracted 370 words
#
# [20/20] Scraping: Age-old tamarind tree on Mettupalayam Road in Coim...
# URL: https://www.thehindu.com/news/cities/Coimbatore/age-old-tama...
# ✅ Success! Extracted 170 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Mapping of government schools, nearest public libr...
# ✅ Updated: TVK cadre attend AIADMK campaign voluntarily: Edap...
# ✅ Updated: Two accused get bail in Armstrong murder case...
# ✅ Updated: Two from Kerala held for snatching imitation gold ...
# ✅ Updated: Two persons arrested for GST fraud in Chennai...
# ✅ Updated: Online/ Vibe Check/Why Gen Z in Chennai is celebra...
# ✅ Updated: Kalaignar Magalir Urimai Thittam helps beneficiari...
# ✅ Updated: State Planning Commission report on startups calls...
# ✅ Updated: Unorganised workers demand resolution in T.N. Asse...
# ✅ Updated: Minister inspects development works in Royapuram z...
# ✅ Updated: Two die in road accident in Singampunari...
# ✅ Updated: Madras High Court reserves orders on retired IPS o...
# ✅ Updated: Two held in separate hoax bomb threat cases in Che...
# ✅ Updated: NCB Southern Region gets new Deputy Director-Gener...
# ✅ Updated: RGGGH performs cross-hand replantation on 28-year-...
# ✅ Updated: T.N. to get more weather radars; new facility laun...
# ✅ Updated: Train services hit on Rameswaram-Ramanathapuram se...
# ✅ Updated: Dindigul campus connect...
# ✅ Updated: Tamil Nadu Assembly adopts resolution mourning Kar...
# ✅ Updated: Age-old tamarind tree on Mettupalayam Road in Coim...
#
# 🔄 Processing batch 4...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Rain to steadily increase over Tamil Nadu this wee...
# URL: https://www.thehindu.com/news/national/tamil-nadu/rain-to-st...
# ✅ Success! Extracted 338 words
#
# [2/20] Scraping: Indian and Japanese governments support research p...
# URL: https://www.thehindu.com/news/cities/chennai/indian-and-japa...
# ✅ Success! Extracted 358 words
#
# [3/20] Scraping: Four held for illegal possession of e-cigarettes...
# URL: https://www.thehindu.com/news/cities/chennai/four-held-for-i...
# ✅ Success! Extracted 151 words
#
# [4/20] Scraping: Persons with disability demand 200 km pathway acro...
# URL: https://www.thehindu.com/news/cities/chennai/persons-with-di...
# ✅ Success! Extracted 322 words
#
# [5/20] Scraping: Made of Chennai Kolu Kondattam 2025 concludes...
# URL: https://www.thehindu.com/news/cities/chennai/made-of-chennai...
# ✅ Success! Extracted 234 words
#
# [6/20] Scraping: City Police steps up security in busy shopping hub...
# URL: https://www.thehindu.com/news/cities/chennai/city-police-ste...
# ✅ Success! Extracted 330 words
#
# [7/20] Scraping: Bulk LPG transporters strike: oil marketing compan...
# URL: https://www.thehindu.com/news/cities/chennai/bulk-lpg-transp...
# ✅ Success! Extracted 268 words
#
# [8/20] Scraping: Lawyers stage road roko against VCK cadres...
# URL: https://www.thehindu.com/news/national/tamil-nadu/lawyers-st...
# ✅ Success! Extracted 122 words
#
# [9/20] Scraping: After SC order, govt. to hold three special TETs i...
# URL: https://www.thehindu.com/news/cities/chennai/after-sc-order-...
# ✅ Success! Extracted 278 words
#
# [10/20] Scraping: New law college building inaugurated...
# URL: https://www.thehindu.com/news/cities/Madurai/new-law-college...
# ✅ Success! Extracted 125 words
#
# [11/20] Scraping: CJ given warm welcome at Madurai Bench...
# URL: https://www.thehindu.com/news/cities/Madurai/cj-given-warm-w...
# ✅ Success! Extracted 313 words
#
# [12/20] Scraping: SHRC orders compensation to woman for police exces...
# URL: https://www.thehindu.com/news/cities/chennai/shrc-orders-com...
# ✅ Success! Extracted 258 words
#
# [13/20] Scraping: Chennai Metro Rail brings on board third contracto...
# URL: https://www.thehindu.com/news/cities/chennai/chennai-metro-r...
# ✅ Success! Extracted 388 words
#
# [14/20] Scraping: Gold from 21 temples fetching over ₹17 crore as ye...
# URL: https://www.thehindu.com/news/cities/chennai/gold-from-21-te...
# ✅ Success! Extracted 189 words
#
# [15/20] Scraping: Chief Minister M.K. Stalin inaugurates mega food p...
# URL: https://www.thehindu.com/news/national/tamil-nadu/chief-mini...
# ✅ Success! Extracted 280 words
#
# [16/20] Scraping: Armed men hack murder case accused in broad daylig...
# URL: https://www.thehindu.com/news/cities/Coimbatore/armed-men-ha...
# ✅ Success! Extracted 268 words
#
# [17/20] Scraping: Obituary reference to be read over Karur stampede ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/obituary-r...
# ✅ Success! Extracted 170 words
#
# [18/20] Scraping: AICC in-charge Girish Chodankar urges TNCC leaders...
# URL: https://www.thehindu.com/news/national/tamil-nadu/aicc-in-ch...
# ✅ Success! Extracted 276 words
#
# [19/20] Scraping: Coimbatore’s G.D. Naidu flyover: motorists demand ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/gd-naidu-fly...
# ✅ Success! Extracted 511 words
#
# [20/20] Scraping: Hoax bomb threat to Mullaperiyar dam...
# URL: https://www.thehindu.com/news/cities/Madurai/hoax-bomb-threa...
# ✅ Success! Extracted 140 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Rain to steadily increase over Tamil Nadu this wee...
# ✅ Updated: Indian and Japanese governments support research p...
# ✅ Updated: Four held for illegal possession of e-cigarettes...
# ✅ Updated: Persons with disability demand 200 km pathway acro...
# ✅ Updated: Made of Chennai Kolu Kondattam 2025 concludes...
# ✅ Updated: City Police steps up security in busy shopping hub...
# ✅ Updated: Bulk LPG transporters strike: oil marketing compan...
# ✅ Updated: Lawyers stage road roko against VCK cadres...
# ✅ Updated: After SC order, govt. to hold three special TETs i...
# ✅ Updated: New law college building inaugurated...
# ✅ Updated: CJ given warm welcome at Madurai Bench...
# ✅ Updated: SHRC orders compensation to woman for police exces...
# ✅ Updated: Chennai Metro Rail brings on board third contracto...
# ✅ Updated: Gold from 21 temples fetching over ₹17 crore as ye...
# ✅ Updated: Chief Minister M.K. Stalin inaugurates mega food p...
# ✅ Updated: Armed men hack murder case accused in broad daylig...
# ✅ Updated: Obituary reference to be read over Karur stampede ...
# ✅ Updated: AICC in-charge Girish Chodankar urges TNCC leaders...
# ✅ Updated: Coimbatore’s G.D. Naidu flyover: motorists demand ...
# ✅ Updated: Hoax bomb threat to Mullaperiyar dam...
#
# 🔄 Processing batch 5...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Police should not be bound by political orders, sa...
# URL: https://www.thehindu.com/news/cities/Madurai/police-should-n...
# ✅ Success! Extracted 245 words
#
# [2/20] Scraping: NHAI plans to use all municipal waste in road cons...
# URL: https://www.thehindu.com/news/cities/chennai/nhai-plans-to-u...
# ✅ Success! Extracted 321 words
#
# [3/20] Scraping: T.N. Idol Wing Police step up efforts to recover t...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tn-idol-wi...
# ✅ Success! Extracted 629 words
#
# [4/20] Scraping: AICCTU demands Deepavali bonus for Thoothukudi Cor...
# URL: https://www.thehindu.com/news/cities/Madurai/aicctu-demands-...
# ✅ Success! Extracted 138 words
#
# [5/20] Scraping: 1.4 lakh people in Chennai, neighbouring areas iss...
# URL: https://www.thehindu.com/news/national/tamil-nadu/14-lakh-pe...
# ✅ Success! Extracted 222 words
#
# [6/20] Scraping: Residents flag inadequate drinking water supply in...
# URL: https://www.thehindu.com/news/cities/Madurai/residents-flag-...
# ✅ Success! Extracted 255 words
#
# [7/20] Scraping: Children’s park opened on Police Commissioner’s of...
# URL: https://www.thehindu.com/news/cities/Coimbatore/childrens-pa...
# ✅ Success! Extracted 112 words
#
# [8/20] Scraping: HC takes serious view of vast extent of temple lan...
# URL: https://www.thehindu.com/news/cities/Madurai/hc-takes-seriou...
# ✅ Success! Extracted 328 words
#
# [9/20] Scraping: BJP yatra will unseat DMK government, says Union M...
# URL: https://www.thehindu.com/news/cities/Coimbatore/bjp-yatra-wi...
# ✅ Success! Extracted 169 words
#
# [10/20] Scraping: HC directs Dindigul Collector to renew gun licence...
# URL: https://www.thehindu.com/news/cities/Madurai/hc-directs-dind...
# ✅ Success! Extracted 331 words
#
# [11/20] Scraping: Thenur residents protest demanding collective part...
# URL: https://www.thehindu.com/news/cities/Madurai/thenur-resident...
# ✅ Success! Extracted 188 words
#
# [12/20] Scraping: Sivakasi Council meeting ends amidst chaos...
# URL: https://www.thehindu.com/news/cities/Madurai/sivakasi-counci...
# ✅ Success! Extracted 353 words
#
# [13/20] Scraping: Man opposes daughter’s marriage, murders her husba...
# URL: https://www.thehindu.com/news/cities/Madurai/man-opposes-dau...
# ✅ Success! Extracted 212 words
#
# [14/20] Scraping: Corporation signs MoU with Aravind Eye Hospital fo...
# URL: https://www.thehindu.com/news/cities/Madurai/corporation-sig...
# ✅ Success! Extracted 203 words
#
# [15/20] Scraping: Infrastructure upgrade initiated under Masterplan ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/infrastructu...
# ✅ Success! Extracted 345 words
#
# [16/20] Scraping: Nonagenarian undergoes successful protected angiop...
# URL: https://www.thehindu.com/news/cities/chennai/nonagenarian-un...
# ✅ Success! Extracted 196 words
#
# [17/20] Scraping: Labour diminished to gig workers in a gig economy,...
# URL: https://www.thehindu.com/news/cities/Coimbatore/labour-dimin...
# ✅ Success! Extracted 206 words
#
# [18/20] Scraping: New bus routes flagged off in Krishnagiri...
# URL: https://www.thehindu.com/news/cities/Coimbatore/new-bus-rout...
# ✅ Success! Extracted 152 words
#
# [19/20] Scraping: Two arrested in kidney sale racket remanded in Sal...
# URL: https://www.thehindu.com/news/cities/Coimbatore/two-arrested...
# ✅ Success! Extracted 224 words
#
# [20/20] Scraping: Onion glut triggers price crash in Dindigul wholes...
# URL: https://www.thehindu.com/news/national/tamil-nadu/onion-glut...
# ✅ Success! Extracted 201 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Police should not be bound by political orders, sa...
# ✅ Updated: NHAI plans to use all municipal waste in road cons...
# ✅ Updated: T.N. Idol Wing Police step up efforts to recover t...
# ✅ Updated: AICCTU demands Deepavali bonus for Thoothukudi Cor...
# ✅ Updated: 1.4 lakh people in Chennai, neighbouring areas iss...
# ✅ Updated: Residents flag inadequate drinking water supply in...
# ✅ Updated: Children’s park opened on Police Commissioner’s of...
# ✅ Updated: HC takes serious view of vast extent of temple lan...
# ✅ Updated: BJP yatra will unseat DMK government, says Union M...
# ✅ Updated: HC directs Dindigul Collector to renew gun licence...
# ✅ Updated: Thenur residents protest demanding collective part...
# ✅ Updated: Sivakasi Council meeting ends amidst chaos...
# ✅ Updated: Man opposes daughter’s marriage, murders her husba...
# ✅ Updated: Corporation signs MoU with Aravind Eye Hospital fo...
# ✅ Updated: Infrastructure upgrade initiated under Masterplan ...
# ✅ Updated: Nonagenarian undergoes successful protected angiop...
# ✅ Updated: Labour diminished to gig workers in a gig economy,...
# ✅ Updated: New bus routes flagged off in Krishnagiri...
# ✅ Updated: Two arrested in kidney sale racket remanded in Sal...
# ✅ Updated: Onion glut triggers price crash in Dindigul wholes...
#
# 🔄 Processing batch 6...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Four-year-old girl dies, father sustains injuries ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/four-year-ol...
# ✅ Success! Extracted 121 words
#
# [2/20] Scraping: District Collector distributes welfare assistance ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/district-col...
# ✅ Success! Extracted 195 words
#
# [3/20] Scraping: Food street works nearing completion in Salem city...
# URL: https://www.thehindu.com/news/cities/Coimbatore/food-street-...
# ✅ Success! Extracted 231 words
#
# [4/20] Scraping: Officials to keep close watch on 27 places vulnera...
# URL: https://www.thehindu.com/news/cities/Madurai/officials-to-ke...
# ✅ Success! Extracted 367 words
#
# [5/20] Scraping: ‘Tamil Nadu should take steps to prevent farmers’ ...
# URL: https://www.thehindu.com/news/cities/Madurai/tamil-nadu-shou...
# ✅ Success! Extracted 402 words
#
# [6/20] Scraping: DVAC arrests panchayat secretary, computer operato...
# URL: https://www.thehindu.com/news/cities/Coimbatore/dvac-arrests...
# ✅ Success! Extracted 292 words
#
# [7/20] Scraping: Connect event in Coimbatore on October 16, 17...
# URL: https://www.thehindu.com/news/cities/Coimbatore/connect-even...
# ✅ Success! Extracted 286 words
#
# [8/20] Scraping: Villagers oppose plan to open liquor shop near pla...
# URL: https://www.thehindu.com/news/cities/Madurai/villagers-oppos...
# ✅ Success! Extracted 390 words
#
# [9/20] Scraping: 100 devotees from Erode begin four-day spiritual p...
# URL: https://www.thehindu.com/news/cities/Coimbatore/100-devotees...
# ✅ Success! Extracted 184 words
#
# [10/20] Scraping: TNPL exploring scope to initiate Coimbatore farmer...
# URL: https://www.thehindu.com/news/cities/Coimbatore/tnpl-explori...
# ✅ Success! Extracted 294 words
#
# [11/20] Scraping: Powerloom federation urges State Govt. to restore ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/powerloom-fe...
# ✅ Success! Extracted 265 words
#
# [12/20] Scraping: Worker from Bihar falls into paper pulp tank, dies...
# URL: https://www.thehindu.com/news/cities/Madurai/worker-from-bih...
# ✅ Success! Extracted 141 words
#
# [13/20] Scraping: Villagers seek Governor’s intervention as several ...
# URL: https://www.thehindu.com/news/cities/Madurai/villagers-seek-...
# ✅ Success! Extracted 207 words
#
# [14/20] Scraping: Three arrested for attacking police station, check...
# URL: https://www.thehindu.com/news/cities/Madurai/three-arrested-...
# ✅ Success! Extracted 234 words
#
# [15/20] Scraping: Deepavali purchase rush: police step up vigil at m...
# URL: https://www.thehindu.com/news/cities/Coimbatore/deepavali-pu...
# ✅ Success! Extracted 150 words
#
# [16/20] Scraping: Awareness programme on sustainable agriculture hel...
# URL: https://www.thehindu.com/news/cities/Coimbatore/awareness-pr...
# ✅ Success! Extracted 154 words
#
# [17/20] Scraping: Water level in Mullaperiyar dam stands at 130.45 f...
# URL: https://www.thehindu.com/news/cities/Madurai/water-level-in-...
# ✅ Success! Extracted 104 words
#
# [18/20] Scraping: Madurai Campus Connect...
# URL: https://www.thehindu.com/news/cities/Madurai/madurai-campus-...
# ✅ Success! Extracted 283 words
#
# [19/20] Scraping: Unorganised sector workers demand law to protect w...
# URL: https://www.thehindu.com/news/cities/Madurai/unorganised-sec...
# ✅ Success! Extracted 328 words
#
# [20/20] Scraping: Shops shut as traders, residents of Ward 55 in  Ti...
# URL: https://www.thehindu.com/news/cities/Madurai/shops-shut-as-t...
# ✅ Success! Extracted 309 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Four-year-old girl dies, father sustains injuries ...
# ✅ Updated: District Collector distributes welfare assistance ...
# ✅ Updated: Food street works nearing completion in Salem city...
# ✅ Updated: Officials to keep close watch on 27 places vulnera...
# ✅ Updated: ‘Tamil Nadu should take steps to prevent farmers’ ...
# ✅ Updated: DVAC arrests panchayat secretary, computer operato...
# ✅ Updated: Connect event in Coimbatore on October 16, 17...
# ✅ Updated: Villagers oppose plan to open liquor shop near pla...
# ✅ Updated: 100 devotees from Erode begin four-day spiritual p...
# ✅ Updated: TNPL exploring scope to initiate Coimbatore farmer...
# ✅ Updated: Powerloom federation urges State Govt. to restore ...
# ✅ Updated: Worker from Bihar falls into paper pulp tank, dies...
# ✅ Updated: Villagers seek Governor’s intervention as several ...
# ✅ Updated: Three arrested for attacking police station, check...
# ✅ Updated: Deepavali purchase rush: police step up vigil at m...
# ✅ Updated: Awareness programme on sustainable agriculture hel...
# ✅ Updated: Water level in Mullaperiyar dam stands at 130.45 f...
# ✅ Updated: Madurai Campus Connect...
# ✅ Updated: Unorganised sector workers demand law to protect w...
# ✅ Updated: Shops shut as traders, residents of Ward 55 in  Ti...
#
# 🔄 Processing batch 7...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Protest demanding removal of Tasmac shop in Erode...
# URL: https://www.thehindu.com/news/cities/Coimbatore/protest-dema...
# ✅ Success! Extracted 197 words
#
# [2/20] Scraping: Four police personnel placed under suspension in S...
# URL: https://www.thehindu.com/news/cities/Coimbatore/four-police-...
# ✅ Success! Extracted 149 words
#
# [3/20] Scraping: Watchtowers installed to monitor festival crowds i...
# URL: https://www.thehindu.com/news/cities/Coimbatore/watchtowers-...
# ✅ Success! Extracted 207 words
#
# [4/20] Scraping: Palaniswami blames T.N. government for security la...
# URL: https://www.thehindu.com/news/national/tamil-nadu/palaniswam...
# ✅ Success! Extracted 462 words
#
# [5/20] Scraping: Karur stampede: TVK ignored warnings, party leader...
# URL: https://www.thehindu.com/news/national/tamil-nadu/karur-stam...
# ✅ Success! Extracted 978 words
#
# [6/20] Scraping: Traffic police make additional parking arrangement...
# URL: https://www.thehindu.com/news/cities/chennai/traffic-police-...
# ✅ Success! Extracted 153 words
#
# [7/20] Scraping: Puthalam salt pans witness influx of migratory bir...
# URL: https://www.thehindu.com/news/cities/Madurai/puthalam-salt-p...
# ✅ Success! Extracted 407 words
#
# [8/20] Scraping: 428 individuals rescued from online investment sca...
# URL: https://www.thehindu.com/news/cities/chennai/428-individuals...
# ✅ Success! Extracted 137 words
#
# [9/20] Scraping: Udhayanidhi Stalin reviews monsoon preparedness at...
# URL: https://www.thehindu.com/news/cities/chennai/udhayanidhi-sta...
# ✅ Success! Extracted 319 words
#
# [10/20] Scraping: Two held in Arumbakkam on charges of possession of...
# URL: https://www.thehindu.com/news/cities/chennai/two-held-in-aru...
# ✅ Success! Extracted 209 words
#
# [11/20] Scraping: Death of remand prisoner in 2019: SHRC recommends ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/death-of-r...
# ✅ Success! Extracted 211 words
#
# [12/20] Scraping: Traffic police issue advisory ahead of Deepavali i...
# URL: https://www.thehindu.com/news/cities/chennai/traffic-police-...
# ✅ Success! Extracted 517 words
#
# [13/20] Scraping: Two youth held with country-made bombs...
# URL: https://www.thehindu.com/news/cities/chennai/two-youth-held-...
# ✅ Success! Extracted 64 words
#
# [14/20] Scraping: Grundfos India launches campaign against single-us...
# URL: https://www.thehindu.com/news/cities/chennai/grundfos-india-...
# ✅ Success! Extracted 175 words
#
# [15/20] Scraping: Over 10,000 students benefited under VIT’s scholar...
# URL: https://www.thehindu.com/news/national/tamil-nadu/over-10000...
# ✅ Success! Extracted 273 words
#
# [16/20] Scraping: Clinic to help women tackle menopause transition...
# URL: https://www.thehindu.com/news/cities/chennai/clinic-to-help-...
# ✅ Success! Extracted 204 words
#
# [17/20] Scraping: Fireworks manufacturers’ associations in Sivakasi ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/fireworks-...
# ✅ Success! Extracted 344 words
#
# [18/20] Scraping: Heavy rainfall drenches many parts of Tamil Nadu a...
# URL: https://www.thehindu.com/news/national/tamil-nadu/heavy-rain...
# ✅ Success! Extracted 522 words
#
# [19/20] Scraping: Wild Tamil Nadu documentary to premiere in Chennai...
# URL: https://www.thehindu.com/news/cities/chennai/wild-tamil-nadu...
# ✅ Success! Extracted 115 words
#
# [20/20] Scraping: Webinar on the last mile in the war against polio...
# URL: https://www.thehindu.com/news/cities/chennai/webinar-on-the-...
# ✅ Success! Extracted 152 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Protest demanding removal of Tasmac shop in Erode...
# ✅ Updated: Four police personnel placed under suspension in S...
# ✅ Updated: Watchtowers installed to monitor festival crowds i...
# ✅ Updated: Palaniswami blames T.N. government for security la...
# ✅ Updated: Karur stampede: TVK ignored warnings, party leader...
# ✅ Updated: Traffic police make additional parking arrangement...
# ✅ Updated: Puthalam salt pans witness influx of migratory bir...
# ✅ Updated: 428 individuals rescued from online investment sca...
# ✅ Updated: Udhayanidhi Stalin reviews monsoon preparedness at...
# ✅ Updated: Two held in Arumbakkam on charges of possession of...
# ✅ Updated: Death of remand prisoner in 2019: SHRC recommends ...
# ✅ Updated: Traffic police issue advisory ahead of Deepavali i...
# ✅ Updated: Two youth held with country-made bombs...
# ✅ Updated: Grundfos India launches campaign against single-us...
# ✅ Updated: Over 10,000 students benefited under VIT’s scholar...
# ✅ Updated: Clinic to help women tackle menopause transition...
# ✅ Updated: Fireworks manufacturers’ associations in Sivakasi ...
# ✅ Updated: Heavy rainfall drenches many parts of Tamil Nadu a...
# ✅ Updated: Wild Tamil Nadu documentary to premiere in Chennai...
# ✅ Updated: Webinar on the last mile in the war against polio...
#
# 🔄 Processing batch 8...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: In memory of Anantharamakrishnan, a pioneering ind...
# URL: https://www.thehindu.com/news/cities/chennai/in-memory-of-a-...
# ✅ Success! Extracted 630 words
#
# [2/20] Scraping: Aavin sells sweets at affordable price ahead of th...
# URL: https://www.thehindu.com/news/cities/chennai/aavin-sells-swe...
# ✅ Success! Extracted 231 words
#
# [3/20] Scraping: Hindu Mahasabha’s T.N. president held under POCSO ...
# URL: https://www.thehindu.com/news/cities/chennai/hindu-mahasabha...
# ✅ Success! Extracted 171 words
#
# [4/20] Scraping: Tamil Nadu’s last Congress Chief Minister Bhaktava...
# URL: https://www.thehindu.com/news/national/tamil-nadu/bhaktavats...
# ✅ Success! Extracted 1008 words
#
# [5/20] Scraping: Doctors emphasise on early identification of strok...
# URL: https://www.thehindu.com/news/cities/chennai/doctors-emphasi...
# ✅ Success! Extracted 189 words
#
# [6/20] Scraping: Govt. deploys 500 ambulances ahead of Deepavali fe...
# URL: https://www.thehindu.com/news/cities/chennai/govt-deploys-50...
# ✅ Success! Extracted 355 words
#
# [7/20] Scraping: Chennai’s 108 ambulances record quick response tim...
# URL: https://www.thehindu.com/news/cities/chennai/chennais-108-am...
# ✅ Success! Extracted 368 words
#
# [8/20] Scraping: Northeast monsoon likely to arrive in Tamil Nadu b...
# URL: https://www.thehindu.com/news/national/tamil-nadu/northeast-...
# ✅ Success! Extracted 257 words
#
# [9/20] Scraping: Bomb threat sent to music director Ilaiyaraaja’s s...
# URL: https://www.thehindu.com/news/cities/chennai/bomb-threat-sen...
# ✅ Success! Extracted 165 words
#
# [10/20] Scraping: VIT Chennai and Deakin University launch dual degr...
# URL: https://www.thehindu.com/news/cities/chennai/vit-chennai-and...
# ✅ Success! Extracted 251 words
#
# [11/20] Scraping: Service lane of Chennai-Bengaluru highway waterlog...
# URL: https://www.thehindu.com/news/national/tamil-nadu/service-la...
# ✅ Success! Extracted 397 words
#
# [12/20] Scraping: Transport Commissioner announces phone numbers for...
# URL: https://www.thehindu.com/news/cities/chennai/transport-commi...
# ✅ Success! Extracted 97 words
#
# [13/20] Scraping: 12-year-old killed as truck hits her near Pulianth...
# URL: https://www.thehindu.com/news/cities/chennai/12-year-old-kil...
# ✅ Success! Extracted 115 words
#
# [14/20] Scraping: Chennai Corporation to regulate vendors at Marina ...
# URL: https://www.thehindu.com/news/cities/chennai/gcc-to-regulate...
# ✅ Success! Extracted 248 words
#
# [15/20] Scraping: How cable TV network came under Tamil Nadu governm...
# URL: https://www.thehindu.com/news/national/tamil-nadu/how-cable-...
# ✅ Success! Extracted 1154 words
#
# [16/20] Scraping: Students shine in quiz on heart health awareness...
# URL: https://www.thehindu.com/news/cities/chennai/students-shine-...
# ✅ Success! Extracted 225 words
#
# [17/20] Scraping: 52-year-old man with osteoarthritis treated using ...
# URL: https://www.thehindu.com/news/cities/chennai/52-year-old-man...
# ✅ Success! Extracted 173 words
#
# [18/20] Scraping: 3 history-sheeters arrested for assaulting biryani...
# URL: https://www.thehindu.com/news/cities/chennai/3-history-sheet...
# ✅ Success! Extracted 182 words
#
# [19/20] Scraping: Nine arrested for murder of real estate businessma...
# URL: https://www.thehindu.com/news/cities/chennai/nine-arrested-f...
# ✅ Success! Extracted 188 words
#
# [20/20] Scraping: Bulk LPG carriers withdraw strike...
# URL: https://www.thehindu.com/news/cities/chennai/bulk-lpg-carrie...
# ✅ Success! Extracted 105 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: In memory of Anantharamakrishnan, a pioneering ind...
# ✅ Updated: Aavin sells sweets at affordable price ahead of th...
# ✅ Updated: Hindu Mahasabha’s T.N. president held under POCSO ...
# ✅ Updated: Tamil Nadu’s last Congress Chief Minister Bhaktava...
# ✅ Updated: Doctors emphasise on early identification of strok...
# ✅ Updated: Govt. deploys 500 ambulances ahead of Deepavali fe...
# ✅ Updated: Chennai’s 108 ambulances record quick response tim...
# ✅ Updated: Northeast monsoon likely to arrive in Tamil Nadu b...
# ✅ Updated: Bomb threat sent to music director Ilaiyaraaja’s s...
# ✅ Updated: VIT Chennai and Deakin University launch dual degr...
# ✅ Updated: Service lane of Chennai-Bengaluru highway waterlog...
# ✅ Updated: Transport Commissioner announces phone numbers for...
# ✅ Updated: 12-year-old killed as truck hits her near Pulianth...
# ✅ Updated: Chennai Corporation to regulate vendors at Marina ...
# ✅ Updated: How cable TV network came under Tamil Nadu governm...
# ✅ Updated: Students shine in quiz on heart health awareness...
# ✅ Updated: 52-year-old man with osteoarthritis treated using ...
# ✅ Updated: 3 history-sheeters arrested for assaulting biryani...
# ✅ Updated: Nine arrested for murder of real estate businessma...
# ✅ Updated: Bulk LPG carriers withdraw strike...
#
# 🔄 Processing batch 9...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: T.N. emerging as a high quality host for internati...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tn-emergin...
# ✅ Success! Extracted 284 words
#
# [2/20] Scraping: Kochi - Salem steel gas pipeilne work resumes afte...
# URL: https://www.thehindu.com/news/national/tamil-nadu/kochi-sale...
# ✅ Success! Extracted 214 words
#
# [3/20] Scraping: Thirumavalavan, VCK MLAs call on Chief Minister M....
# URL: https://www.thehindu.com/news/national/tamil-nadu/thirumaval...
# ✅ Success! Extracted 59 words
#
# [4/20] Scraping: Annual conference of Collectors, police officers o...
# URL: https://www.thehindu.com/news/national/tamil-nadu/annual-con...
# ✅ Success! Extracted 64 words
#
# [5/20] Scraping: Supreme Court’s observations on Mullaperiyar dam a...
# URL: https://www.thehindu.com/news/national/tamil-nadu/supreme-co...
# ✅ Success! Extracted 208 words
#
# [6/20] Scraping: Activists condemn caste discrimination in Kodiyaka...
# URL: https://www.thehindu.com/news/cities/chennai/activists-conde...
# ✅ Success! Extracted 273 words
#
# [7/20] Scraping: Two events in Chennai on October 25 to promote rep...
# URL: https://www.thehindu.com/news/cities/chennai/two-events-in-c...
# ✅ Success! Extracted 526 words
#
# [8/20] Scraping: Crimes against women, children, and the elderly on...
# URL: https://www.thehindu.com/news/national/tamil-nadu/crimes-aga...
# ✅ Success! Extracted 180 words
#
# [9/20] Scraping: CMC launches specialised team for patients affecte...
# URL: https://www.thehindu.com/news/national/tamil-nadu/cmc-launch...
# ✅ Success! Extracted 177 words
#
# [10/20] Scraping: Impleading victim’s parents is key to bail in POCS...
# URL: https://www.thehindu.com/news/national/tamil-nadu/impleading...
# ✅ Success! Extracted 470 words
#
# [11/20] Scraping: Karur stampede: AIADMK, BJP, TVK welcome Supreme C...
# URL: https://www.thehindu.com/news/national/tamil-nadu/karur-stam...
# ✅ Success! Extracted 362 words
#
# [12/20] Scraping: Three die in Coimbatore as speeding car descending...
# URL: https://www.thehindu.com/news/cities/Coimbatore/three-die-in...
# ✅ Success! Extracted 247 words
#
# [13/20] Scraping: Woman, three-year-old granddaughter killed in elep...
# URL: https://www.thehindu.com/news/national/tamil-nadu/woman-gran...
# ✅ Success! Extracted 198 words
#
# [14/20] Scraping: Teenage boy found dead in Madurai...
# URL: https://www.thehindu.com/news/cities/Madurai/teenage-boy-fou...
# ✅ Success! Extracted 125 words
#
# [15/20] Scraping: Coimbatore Collector urges sweet manufacturers and...
# URL: https://www.thehindu.com/news/cities/Coimbatore/coimbatore-c...
# ✅ Success! Extracted 245 words
#
# [16/20] Scraping: First phase of western bypass in Coimbatore city t...
# URL: https://www.thehindu.com/news/cities/Coimbatore/first-phase-...
# ✅ Success! Extracted 287 words
#
# [17/20] Scraping: AIADWA seek increase of MGNREGA workdays...
# URL: https://www.thehindu.com/news/cities/Madurai/aiadwa-seek-inc...
# ✅ Success! Extracted 161 words
#
# [18/20] Scraping: Hotel in M. Reddiyapatti closed after moth was fou...
# URL: https://www.thehindu.com/news/cities/Madurai/hotel-in-m-redd...
# ✅ Success! Extracted 87 words
#
# [19/20] Scraping: Leopard sighting in Hosur puts residents, Forest D...
# URL: https://www.thehindu.com/news/cities/Coimbatore/leopard-sigh...
# ✅ Success! Extracted 118 words
#
# [20/20] Scraping: Motorists seek traffic signal at Sitra junction in...
# URL: https://www.thehindu.com/news/cities/Coimbatore/motorists-se...
# ✅ Success! Extracted 303 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: T.N. emerging as a high quality host for internati...
# ✅ Updated: Kochi - Salem steel gas pipeilne work resumes afte...
# ✅ Updated: Thirumavalavan, VCK MLAs call on Chief Minister M....
# ✅ Updated: Annual conference of Collectors, police officers o...
# ✅ Updated: Supreme Court’s observations on Mullaperiyar dam a...
# ✅ Updated: Activists condemn caste discrimination in Kodiyaka...
# ✅ Updated: Two events in Chennai on October 25 to promote rep...
# ✅ Updated: Crimes against women, children, and the elderly on...
# ✅ Updated: CMC launches specialised team for patients affecte...
# ✅ Updated: Impleading victim’s parents is key to bail in POCS...
# ✅ Updated: Karur stampede: AIADMK, BJP, TVK welcome Supreme C...
# ✅ Updated: Three die in Coimbatore as speeding car descending...
# ✅ Updated: Woman, three-year-old granddaughter killed in elep...
# ✅ Updated: Teenage boy found dead in Madurai...
# ✅ Updated: Coimbatore Collector urges sweet manufacturers and...
# ✅ Updated: First phase of western bypass in Coimbatore city t...
# ✅ Updated: AIADWA seek increase of MGNREGA workdays...
# ✅ Updated: Hotel in M. Reddiyapatti closed after moth was fou...
# ✅ Updated: Leopard sighting in Hosur puts residents, Forest D...
# ✅ Updated: Motorists seek traffic signal at Sitra junction in...
#
# 🔄 Processing batch 10...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Bio diversity conservation project undertaken in N...
# URL: https://www.thehindu.com/news/cities/Coimbatore/bio-diversit...
# ✅ Success! Extracted 205 words
#
# [2/20] Scraping: Workers’ hostel at Kurichi in Coimbatore gets a fe...
# URL: https://www.thehindu.com/news/cities/Coimbatore/workers-host...
# ✅ Success! Extracted 335 words
#
# [3/20] Scraping: Boy dies of rabies in Coimbatore...
# URL: https://www.thehindu.com/news/cities/Coimbatore/boy-dies-of-...
# ✅ Success! Extracted 78 words
#
# [4/20] Scraping: TASE Global acquires Joined Alloys...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tase-globa...
# ✅ Success! Extracted 331 words
#
# [5/20] Scraping: Nurses demand regularisation of job, post letter t...
# URL: https://www.thehindu.com/news/cities/Madurai/nurses-demand-r...
# ✅ Success! Extracted 329 words
#
# [6/20] Scraping: Traffic regulation in city in view of Deepavali fr...
# URL: https://www.thehindu.com/news/cities/Madurai/traffic-regulat...
# ✅ Success! Extracted 202 words
#
# [7/20] Scraping: Ramanathapuram fishermen seek action against Puduc...
# URL: https://www.thehindu.com/news/cities/Madurai/ramanathapuram-...
# ✅ Success! Extracted 301 words
#
# [8/20] Scraping: Body of newborn found in Government Villupuram Med...
# URL: https://www.thehindu.com/news/national/tamil-nadu/body-of-ne...
# ✅ Success! Extracted 112 words
#
# [9/20] Scraping: Unclaimed SSLC marksheets can be collected till Oc...
# URL: https://www.thehindu.com/news/cities/Coimbatore/unclaimed-ss...
# ✅ Success! Extracted 132 words
#
# [10/20] Scraping: Schemes worth ₹212.41 crore implemented in Ayothiy...
# URL: https://www.thehindu.com/news/cities/Coimbatore/schemes-wort...
# ✅ Success! Extracted 201 words
#
# [11/20] Scraping: Over 83,100 people have used 108 ambulance service...
# URL: https://www.thehindu.com/news/cities/Coimbatore/over-83100-p...
# ✅ Success! Extracted 255 words
#
# [12/20] Scraping: Special camp in Erode to handover unclaimed bank d...
# URL: https://www.thehindu.com/news/cities/Coimbatore/special-camp...
# ✅ Success! Extracted 170 words
#
# [13/20] Scraping: RPF conducts awareness campaign for train passenge...
# URL: https://www.thehindu.com/news/cities/Coimbatore/rpf-conducts...
# ✅ Success! Extracted 193 words
#
# [14/20] Scraping: Plea to expand MGNREGS to urban areas in Erode...
# URL: https://www.thehindu.com/news/cities/Coimbatore/plea-to-expa...
# ✅ Success! Extracted 229 words
#
# [15/20] Scraping: Coimbatore Corporation plans ₹12-crore Paralympic ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/coimbatore-c...
# ✅ Success! Extracted 318 words
#
# [16/20] Scraping: ‘Indian team to play in Junior World Cup Hockey ma...
# URL: https://www.thehindu.com/news/cities/Madurai/indian-team-to-...
# ✅ Success! Extracted 327 words
#
# [17/20] Scraping: Brisk business at weekly textile market in Erode a...
# URL: https://www.thehindu.com/news/cities/Coimbatore/brisk-busine...
# ✅ Success! Extracted 254 words
#
# [18/20] Scraping: ‘V.O.C Port outer harbour development undergoing r...
# URL: https://www.thehindu.com/news/cities/Madurai/voc-port-outer-...
# ✅ Success! Extracted 681 words
#
# [19/20] Scraping: Tamil Nadu CM Stalin reiterates request to Modi to...
# URL: https://www.thehindu.com/news/national/tamil-nadu/stalin-rei...
# ...
# ✅ Success! Extracted 623 words
#
# [19/20] Scraping: Adichanallur site faces weather threats, semi-perm...
# URL: https://www.thehindu.com/news/cities/Madurai/adichanallur-si...
# ✅ Success! Extracted 253 words
#
# [20/20] Scraping: First flood warning issued in Vaigai dam; storage ...
# URL: https://www.thehindu.com/news/cities/Madurai/first-flood-war...
# ✅ Success! Extracted 79 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: LAX/Wet Deepavali likely over Tamil Nadu; RMC fore...
# ✅ Updated: VCK urges Tamil Nadu government to pass law agains...
# ✅ Updated: DPH instructs health officers to take up facility ...
# ✅ Updated: Two-month old baby rescued from smuggler in Tiruva...
# ✅ Updated: IGCAR celebrates a milestone in India’s Nuclear En...
# ✅ Updated: Congress MLA Rajakumar assaults a traffic policema...
# ✅ Updated: MUTA demands roll back of Private Univ Amendment B...
# ✅ Updated: GCC increases relief centres to 215 in view of hea...
# ✅ Updated: Water discharge from Poondi and Red Hills reservoi...
# ✅ Updated: RSR/ Over 7 lakh people leave city to hometowns fo...
# ✅ Updated: Speaker must recognise S.P. Venkateswaran as PMK f...
# ✅ Updated: T.N. govt. doctors body urges Chief Minister to fu...
# ✅ Updated: T.N. BJP names new members to special committee...
# ✅ Updated: ‘We will stand by you’: Vijay’s TVK extends ₹20 la...
# ✅ Updated: Passenger commends Railways for swift action in re...
# ✅ Updated: STS: track tales/ No more long walks: Chennai Metr...
# ✅ Updated: Form board of trustees for Tiruchendur temple in f...
# ✅ Updated: Delay in adoption deprives the child of formative ...
# ✅ Updated: Adichanallur site faces weather threats, semi-perm...
# ✅ Updated: First flood warning issued in Vaigai dam; storage ...
#
# 🔄 Processing batch 24...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Park coming up along B-Canal in Chepauk...
# URL: https://www.thehindu.com/news/cities/chennai/park-coming-up-...
# ✅ Success! Extracted 311 words
#
# [2/20] Scraping: One could take books home at this collection drive...
# URL: https://www.thehindu.com/news/cities/chennai/one-could-take-...
# ✅ Success! Extracted 370 words
#
# [3/20] Scraping: Padikattugal trust distributes new clothes to 107 ...
# URL: https://www.thehindu.com/news/cities/Madurai/padikattugal-tr...
# ✅ Success! Extracted 140 words
#
# [4/20] Scraping: Extended weekend, operation of special trains prev...
# URL: https://www.thehindu.com/news/cities/Madurai/extended-weeken...
# ✅ Success! Extracted 326 words
#
# [5/20] Scraping: Identifying birds by GISS; and if that fails, by t...
# URL: https://www.thehindu.com/news/cities/chennai/identifying-bir...
# ✅ Success! Extracted 386 words
#
# [6/20] Scraping: Thoothukudi administration warns residents of low-...
# URL: https://www.thehindu.com/news/cities/Madurai/thoothukudi-adm...
# ✅ Success! Extracted 145 words
#
# [7/20] Scraping: Number of seasonal flu cases declines as weather i...
# URL: https://www.thehindu.com/news/cities/Madurai/number-of-seaso...
# ✅ Success! Extracted 376 words
#
# [8/20] Scraping: Minister inaugurates integrated modern police cont...
# URL: https://www.thehindu.com/news/cities/Madurai/minister-inaugu...
# ✅ Success! Extracted 269 words
#
# [9/20] Scraping: Areas closer to Western Ghats record good rainfall...
# URL: https://www.thehindu.com/news/cities/Madurai/areas-closer-to...
# ✅ Success! Extracted 395 words
#
# [10/20] Scraping: CITU transport workers’ 62-day-long wait-in protes...
# URL: https://www.thehindu.com/news/cities/Madurai/citu-transport-...
# ✅ Success! Extracted 284 words
#
# [11/20] Scraping: Amount of subsidies provided by T.N. government ri...
# URL: https://www.thehindu.com/news/national/tamil-nadu/amount-of-...
# ✅ Success! Extracted 344 words
#
# [12/20] Scraping: Man ends life, sons found dead in Hosur...
# URL: https://www.thehindu.com/news/cities/Coimbatore/man-ends-lif...
# ✅ Success! Extracted 157 words
#
# [13/20] Scraping: Subsidy for value addition of agricultural produce...
# URL: https://www.thehindu.com/news/cities/Coimbatore/subsidy-for-...
# ✅ Success! Extracted 171 words
#
# [14/20] Scraping: Coimbatore Corporation seeks ₹274 crore from State...
# URL: https://www.thehindu.com/news/cities/Coimbatore/coimbatore-c...
# ✅ Success! Extracted 234 words
#
# [15/20] Scraping: Tenkasi district has stocked over 2,500 tonnes of ...
# URL: https://www.thehindu.com/news/cities/Madurai/tenkasi-distric...
# ✅ Success! Extracted 450 words
#
# [16/20] Scraping: Made of Chennai Kolu Kondattam 2025: knocking on t...
# URL: https://www.thehindu.com/news/cities/chennai/made-of-chennai...
# ✅ Success! Extracted 526 words
#
# [17/20] Scraping: Emergency Care and Recovery Centre inaugurated at ...
# URL: https://www.thehindu.com/news/cities/Madurai/emergency-care-...
# ✅ Success! Extracted 183 words
#
# [18/20] Scraping: Coimbatore residents urged to call helplines for r...
# URL: https://www.thehindu.com/news/cities/Coimbatore/coimbatore-r...
# ✅ Success! Extracted 157 words
#
# [19/20] Scraping: Coimbatore self-help groups receive ₹9.30 crore in...
# URL: https://www.thehindu.com/news/cities/Coimbatore/coimbatore-s...
# ✅ Success! Extracted 188 words
#
# [20/20] Scraping: Dugong conservation centre being planned in ‘No-De...
# URL: https://www.thehindu.com/news/national/tamil-nadu/dugong-con...
# ✅ Success! Extracted 472 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Park coming up along B-Canal in Chepauk...
# ✅ Updated: One could take books home at this collection drive...
# ✅ Updated: Padikattugal trust distributes new clothes to 107 ...
# ✅ Updated: Extended weekend, operation of special trains prev...
# ✅ Updated: Identifying birds by GISS; and if that fails, by t...
# ✅ Updated: Thoothukudi administration warns residents of low-...
# ✅ Updated: Number of seasonal flu cases declines as weather i...
# ✅ Updated: Minister inaugurates integrated modern police cont...
# ✅ Updated: Areas closer to Western Ghats record good rainfall...
# ✅ Updated: CITU transport workers’ 62-day-long wait-in protes...
# ✅ Updated: Amount of subsidies provided by T.N. government ri...
# ✅ Updated: Man ends life, sons found dead in Hosur...
# ✅ Updated: Subsidy for value addition of agricultural produce...
# ✅ Updated: Coimbatore Corporation seeks ₹274 crore from State...
# ✅ Updated: Tenkasi district has stocked over 2,500 tonnes of ...
# ✅ Updated: Made of Chennai Kolu Kondattam 2025: knocking on t...
# ✅ Updated: Emergency Care and Recovery Centre inaugurated at ...
# ✅ Updated: Coimbatore residents urged to call helplines for r...
# ✅ Updated: Coimbatore self-help groups receive ₹9.30 crore in...
# ✅ Updated: Dugong conservation centre being planned in ‘No-De...
#
# 🔄 Processing batch 25...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Man kills wife in Salem...
# URL: https://www.thehindu.com/news/cities/Coimbatore/man-kills-wi...
# ✅ Success! Extracted 154 words
#
# [2/20] Scraping: Salem district administration announces contact nu...
# URL: https://www.thehindu.com/news/cities/Coimbatore/salem-distri...
# ✅ Success! Extracted 250 words
#
# [3/20] Scraping: Water level rises by six feet in Mullaperiyar dam;...
# URL: https://www.thehindu.com/news/national/tamil-nadu/water-leve...
# ✅ Success! Extracted 467 words
#
# [4/20] Scraping: Rain, online sale of firecrackers affect business,...
# URL: https://www.thehindu.com/news/cities/Coimbatore/rain-online-...
# ✅ Success! Extracted 326 words
#
# [5/20] Scraping: Rain fails to deter Deepavali shoppers as crowd fl...
# URL: https://www.thehindu.com/news/cities/Coimbatore/rain-fails-t...
# ✅ Success! Extracted 334 words
#
# [6/20] Scraping: Despite rains, Tamil Nadu ushers in Deepavali with...
# URL: https://www.thehindu.com/news/national/tamil-nadu/despite-ra...
# ✅ Success! Extracted 316 words
#
# [7/20] Scraping: Red Wood Montessori opens new campus in city to nu...
# URL: https://www.thehindu.com/news/cities/chennai/red-wood-montes...
# ✅ Success! Extracted 277 words
#
# [8/20] Scraping: Low public awareness leaves green firecrackers in ...
# URL: https://www.thehindu.com/news/cities/chennai/low-public-awar...
# ✅ Success! Extracted 399 words
#
# [9/20] Scraping: TNSDA completes the first phase of underwater surv...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tnsda-comp...
# ✅ Success! Extracted 369 words
#
# [10/20] Scraping: Case filed against Cong. MLA for assaulting traffi...
# URL: https://www.thehindu.com/news/cities/chennai/case-filed-agai...
# ✅ Success! Extracted 66 words
#
# [11/20] Scraping: New water pipeline from Sathanur dam to Tiruvannam...
# URL: https://www.thehindu.com/news/national/tamil-nadu/new-water-...
# ✅ Success! Extracted 337 words
#
# [12/20] Scraping: Over 3,500 police personnel deployed in Vellore, n...
# URL: https://www.thehindu.com/news/national/tamil-nadu/over-3500-...
# ✅ Success! Extracted 358 words
#
# [13/20] Scraping: Book vending machines at two railway stations in c...
# URL: https://www.thehindu.com/news/cities/chennai/book-vending-ma...
# ✅ Success! Extracted 313 words
#
# [14/20] Scraping: Don’t relocate primary health centre in Kaduvetti,...
# URL: https://www.thehindu.com/news/national/tamil-nadu/dont-reloc...
# ✅ Success! Extracted 126 words
#
# [15/20] Scraping: 107 places in Chennai have links missing in drain ...
# URL: https://www.thehindu.com/news/cities/chennai/107-places-in-c...
# ✅ Success! Extracted 421 words
#
# [16/20] Scraping: STS/ Chennai Metro Rail ranks high in customer sat...
# URL: https://www.thehindu.com/news/cities/chennai/chennai-metro-r...
# ✅ Success! Extracted 301 words
#
# [17/20] Scraping: DGP appointment row: second contempt petition move...
# URL: https://www.thehindu.com/news/national/tamil-nadu/dgp-appoin...
# ✅ Success! Extracted 315 words
#
# [18/20] Scraping: Low-pressure area likely over southeast Bay of Ben...
# URL: https://www.thehindu.com/news/national/tamil-nadu/low-pressu...
# ✅ Success! Extracted 225 words
#
# [19/20] Scraping: Widespread rainfall brings flooding in parts of Co...
# URL: https://www.thehindu.com/news/cities/Coimbatore/widespread-r...
# ✅ Success! Extracted 227 words
#
# [20/20] Scraping: Man attempts to end life; mother found dead in Coi...
# URL: https://www.thehindu.com/news/cities/Coimbatore/man-attempts...
# ✅ Success! Extracted 218 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Man kills wife in Salem...
# ✅ Updated: Salem district administration announces contact nu...
# ✅ Updated: Water level rises by six feet in Mullaperiyar dam;...
# ✅ Updated: Rain, online sale of firecrackers affect business,...
# ✅ Updated: Rain fails to deter Deepavali shoppers as crowd fl...
# ✅ Updated: Despite rains, Tamil Nadu ushers in Deepavali with...
# ✅ Updated: Red Wood Montessori opens new campus in city to nu...
# ✅ Updated: Low public awareness leaves green firecrackers in ...
# ✅ Updated: TNSDA completes the first phase of underwater surv...
# ✅ Updated: Case filed against Cong. MLA for assaulting traffi...
# ✅ Updated: New water pipeline from Sathanur dam to Tiruvannam...
# ✅ Updated: Over 3,500 police personnel deployed in Vellore, n...
# ✅ Updated: Book vending machines at two railway stations in c...
# ✅ Updated: Don’t relocate primary health centre in Kaduvetti,...
# ✅ Updated: 107 places in Chennai have links missing in drain ...
# ✅ Updated: STS/ Chennai Metro Rail ranks high in customer sat...
# ✅ Updated: DGP appointment row: second contempt petition move...
# ✅ Updated: Low-pressure area likely over southeast Bay of Ben...
# ✅ Updated: Widespread rainfall brings flooding in parts of Co...
# ✅ Updated: Man attempts to end life; mother found dead in Coi...
#
# 🔄 Processing batch 26...
# 🚀 Starting batch scraping: 17 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/17] Scraping: Four killed in a blast at a house in Avadi where c...
# URL: https://www.thehindu.com/news/cities/chennai/four-killed-in-...
# ✅ Success! Extracted 258 words
#
# [2/17] Scraping: Man arrested for electrocution of spotted deer nea...
# URL: https://www.thehindu.com/news/cities/Coimbatore/man-arrested...
# ✅ Success! Extracted 135 words
#
# [3/17] Scraping: 26 ‘Thozhi’ hostels under construction across the ...
# URL: https://www.thehindu.com/news/cities/Madurai/26-thozhi-hoste...
# ✅ Success! Extracted 167 words
#
# [4/17] Scraping: Coimbatore Corporation urged to convene consultati...
# URL: https://www.thehindu.com/news/cities/Coimbatore/coimbatore-c...
# ✅ Success! Extracted 271 words
#
# [5/17] Scraping: DSC jawan found dead at Air Force Station, Sulur i...
# URL: https://www.thehindu.com/news/cities/Coimbatore/dsc-jawan-en...
# ✅ Success! Extracted 284 words
#
# [6/17] Scraping: Rain continues across southern districts; reservoi...
# URL: https://www.thehindu.com/news/cities/Madurai/rain-continues-...
# ✅ Success! Extracted 263 words
#
# [7/17] Scraping: Tamil Nadu government fully prepared to face north...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tamil-nadu...
# ✅ Success! Extracted 313 words
#
# [8/17] Scraping: Down ramps of G.D. Naidu flyover in Coimbatore cit...
# URL: https://www.thehindu.com/news/cities/Coimbatore/down-ramps-o...
# ✅ Success! Extracted 239 words
#
# [9/17] Scraping: Enhanced security in Thoothukudi ahead of Deepaval...
# URL: https://www.thehindu.com/news/cities/Madurai/enhanced-securi...
# ✅ Success! Extracted 231 words
#
# [10/17] Scraping: Crowd swell in busy streets ahead of Deepavali cel...
# URL: https://www.thehindu.com/news/cities/Madurai/crowd-swell-in-...
# ✅ Success! Extracted 432 words
#
# [11/17] Scraping: Tirunelveli reader’s mail...
# URL: https://www.thehindu.com/news/cities/Madurai/tirunelveli-rea...
# ✅ Success! Extracted 428 words
#
# [12/17] Scraping: Travelling public seek regularisation of festival ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/travelling-p...
# ✅ Success! Extracted 520 words
#
# [13/17] Scraping: Over 700 police personnel deployed in Salem city f...
# URL: https://www.thehindu.com/news/cities/Coimbatore/over-700-pol...
# ✅ Success! Extracted 278 words
#
# [14/17] Scraping: Madurai readers’ mail...
# URL: https://www.thehindu.com/news/cities/Madurai/madurai-readers...
# ✅ Success! Extracted 539 words
#
# [15/17] Scraping: Health Department steps up vigil against dengue; m...
# URL: https://www.thehindu.com/news/cities/Coimbatore/health-depar...
# ✅ Success! Extracted 263 words
#
# [16/17] Scraping: High price of silver affects anklet orders for Dee...
# URL: https://www.thehindu.com/news/cities/Coimbatore/high-price-o...
# ✅ Success! Extracted 234 words
#
# [17/17] Scraping: Tamil Nadu’s off-budget borrowings were ₹3,919.10 ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tamil-nadu...
# ✅ Success! Extracted 530 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Four killed in a blast at a house in Avadi where c...
# ✅ Updated: Man arrested for electrocution of spotted deer nea...
# ✅ Updated: 26 ‘Thozhi’ hostels under construction across the ...
# ✅ Updated: Coimbatore Corporation urged to convene consultati...
# ✅ Updated: DSC jawan found dead at Air Force Station, Sulur i...
# ✅ Updated: Rain continues across southern districts; reservoi...
# ✅ Updated: Tamil Nadu government fully prepared to face north...
# ✅ Updated: Down ramps of G.D. Naidu flyover in Coimbatore cit...
# ✅ Updated: Enhanced security in Thoothukudi ahead of Deepaval...
# ✅ Updated: Crowd swell in busy streets ahead of Deepavali cel...
# ✅ Updated: Tirunelveli reader’s mail...
# ✅ Updated: Travelling public seek regularisation of festival ...
# ✅ Updated: Over 700 police personnel deployed in Salem city f...
# ✅ Updated: Madurai readers’ mail...
# ✅ Updated: Health Department steps up vigil against dengue; m...
# ✅ Updated: High price of silver affects anklet orders for Dee...
# ✅ Updated: Tamil Nadu’s off-budget borrowings were ₹3,919.10 ...
#
# ✅ All articles processed!

# %% [markdown]
# ## Final Report & Next Steps

# %%
# Generate final report
print("="*60)
print("📋 FINAL SCRAPING REPORT")
print("="*60)
print(f"\nTest Batch Results:")
print(f"  Attempted: {len(test_batch)}")
print(f"  Successful: {success_count} ({success_rate:.1f}%)")
print(f"  Failed: {failure_count}")
print(f"  Avg Word Count: {successful_df['word_count'].mean():.0f} words")

print(f"\nDatabase Status:")
print(f"  Total articles in DB: 150")
print(f"  With full content: {with_content.count}")
print(f"  Still need scraping: {remaining.count}")

print(f"\nNext Steps:")
if success_rate > 70:
    print("  ✅ Success rate is good! Process remaining articles.")
elif success_rate > 50:
    print("  ⚠️  Success rate is moderate. Review failed extractions.")
    print("  ⚠️  Consider adjusting extraction parameters")
else:
    print("  ❌ Success rate is low. May need custom scraper.")
    print("  ❌ Review The Hindu's HTML structure manually")

print("\n" + "="*60)
# Out:
# ============================================================
# 📋 FINAL SCRAPING REPORT
# ============================================================
#
# Test Batch Results:
#   Attempted: 10
#   Successful: 10 (100.0%)
#   Failed: 0
#   Avg Word Count: 435 words
#
# Database Status:
#   Total articles in DB: 150
#   With full content: 755
#   Still need scraping: 517
#
# Next Steps:
#   ✅ Success rate is good! Process remaining articles.
#   ✅ Uncomment the 'process-remaining' cell to scrape all
#
# ============================================================
