# %% [markdown]
# # 04: Full-Text Article Scraper
# **Goal**: Extract full article content for records missing descriptions
#
# **Strategy**:
# 1. Test trafilatura on sample articles
# 2. Fetch articles needing scraping from Supabase
# 3. Extract content in batches with error handling
# 4. Update database with extracted content
# 5. Generate quality report
#
# **Target**: 82 articles (50 archive + 32 RSS without descriptions)

# %% [markdown]
# ## Phase 1: Setup & Library Testing

# %%
# Install required libraries (run once)
# !pip install trafilatura supabase python-dotenv requests

import trafilatura
from supabase import create_client, Client
import requests
import pandas as pd
from datetime import datetime
import time
from typing import List, Dict, Tuple
import json

print("✅ Libraries imported successfully")
print(f"Trafilatura version: {trafilatura.__version__}")
# Out:
# ✅ Libraries imported successfully
# Trafilatura version: 2.0.0

# %%
# ============================================
# SUPABASE CREDENTIALS - REPLACE THESE
# ============================================
SUPABASE_URL = "https://lgnhjzlbezpczlobeevu.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImxnbmhqemxiZXpwY3psb2JlZXZ1Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTgyMDgzNjcsImV4cCI6MjA3Mzc4NDM2N30.O5Yt0dOyYq326ESo0LBL7lGj4k8zwpuodJfTtGwrPek"
# ============================================

# Initialize Supabase client
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

print("✅ Supabase client initialized!")
print(f"Connected to: {SUPABASE_URL}")
# Out:
# ✅ Supabase client initialized!
# Connected to: https://lgnhjzlbezpczlobeevu.supabase.co

# %%
# Test trafilatura on a single article
TEST_URL = "https://www.thehindu.com/news/national/tamil-nadu/encroachments-demolished-to-complete-new-bridge-across-kamadalam-river-near-arani/article70102100.ece"

print(f"🧪 Testing extraction on: {TEST_URL}\n")
print("="*60)

try:
    # Download HTML
    downloaded = trafilatura.fetch_url(TEST_URL)
    
    if downloaded:
        # Extract content
        content = trafilatura.extract(downloaded, include_comments=False, include_tables=False)
        
        if content:
            print("✅ Extraction Successful!\n")
            print(f"Content Length: {len(content)} characters")
            print(f"Word Count: ~{len(content.split())} words\n")
            print("First 500 characters:")
            print("-"*60)
            print(content[:500])
            print("-"*60)
        else:
            print("⚠️ Extraction returned empty content")
    else:
        print("❌ Failed to download page")
        
except Exception as e:
    print(f"❌ Error: {e}")

print("\n💡 If extraction worked, proceed. If failed, we'll need a custom scraper.")
# Out:
# 🧪 Testing extraction on: https://www.thehindu.com/news/national/tamil-nadu/encroachments-demolished-to-complete-new-bridge-across-kamadalam-river-near-arani/article70102100.ece
#
# ============================================================
# ✅ Extraction Successful!
#
# Content Length: 2234 characters
# Word Count: ~374 words
#
# First 500 characters:
# ------------------------------------------------------------
# The State Highways Department demolished encroachments on Arcot - Villupuram Main Road (SH-4) near old bus terminus in Arani town in Tiruvannamalai to lay bitumen approach roads as part of completion of the two-lane high level bridge across Kamadalam Naganathi river.
# Officials of State Highways, which is constructing the bridge, said that most of the encroachments are houses and petty shops, which were built more than two decades ago. Encroached land near the bus terminus belongs to State Highwa
# ------------------------------------------------------------
#
# 💡 If extraction worked, proceed. If failed, we'll need a custom scraper.

# %% [markdown]
# ## Phase 2: Fetch Target Articles from Database

# %%
# Fetch all articles needing full-text scraping
print("📥 Fetching articles that need scraping...\n")

result = supabase.table('news_cleaned') \
    .select('id, title, link, source, category') \
    .eq('needs_full_scrape', True) \
    .execute()

articles_to_scrape = result.data

print("="*60)
print("📊 ARTICLES NEEDING SCRAPING")
print("="*60)
print(f"Total: {len(articles_to_scrape)} articles\n")

# Breakdown by source
df_scrape = pd.DataFrame(articles_to_scrape)
source_counts = df_scrape['source'].value_counts()

print("By Source:")
for source, count in source_counts.items():
    print(f"  {source}: {count}")

# Category breakdown
print("\nBy Category:")
category_counts = df_scrape['category'].value_counts()
for cat, count in category_counts.head(5).items():
    print(f"  {cat}: {count}")

print("\n💡 Recommendation: Start with 20 articles (10 archive + 10 RSS) for testing")
# Out:
# 📥 Fetching articles that need scraping...
#
# ============================================================
# 📊 ARTICLES NEEDING SCRAPING
# ============================================================
# Total: 462 articles
#
# By Source:
#   The Hindu - Archive: 462
#
# By Category:
#   Tamil Nadu: 144
#   Madurai: 126
#   Coimbatore: 102
#   Chennai: 90
#
# 💡 Recommendation: Start with 20 articles (10 archive + 10 RSS) for testing

# %%
# Select test batch: 10 archive + 10 RSS
archive_articles = [a for a in articles_to_scrape if 'Archive' in a['source']][:10]
rss_articles = [a for a in articles_to_scrape if 'RSS' in a['source']][:10]

test_batch = archive_articles + rss_articles

print("🎯 TEST BATCH SELECTED")
print("="*60)
print(f"Archive articles: {len(archive_articles)}")
print(f"RSS articles: {len(rss_articles)}")
print(f"Total test batch: {len(test_batch)}\n")

print("Sample articles:")
for i, article in enumerate(test_batch[:3], 1):
    print(f"\n{i}. [{article['source']}]")
    print(f"   {article['title'][:60]}...")
    print(f"   {article['link'][:70]}...")
# Out:
# 🎯 TEST BATCH SELECTED
# ============================================================
# Archive articles: 10
# RSS articles: 0
# Total test batch: 10
#
# Sample articles:
#
# 1. [The Hindu - Archive]
#    Mother kills child, ends life in Erode...
#    https://www.thehindu.com/news/cities/Coimbatore/mother-kills-child-end...
#
# 2. [The Hindu - Archive]
#    Bar employee arrested for murdering Salem native near Coimba...
#    https://www.thehindu.com/news/cities/Coimbatore/bar-employee-arrested-...
#
# 3. [The Hindu - Archive]
#    UGD charges to be collected as per 2023 bylaw, says Coimbato...
#    https://www.thehindu.com/news/cities/Coimbatore/ugd-charges-to-be-coll...

# %% [markdown]
# ## Phase 3: Content Extraction Pipeline

# %%
def extract_article_content(url: str, max_retries: int = 3, timeout: int = 10) -> Dict:
    """
    Extract full article content from URL using trafilatura
    
    Returns:
        Dict with keys: success, content, error, word_count
    """
    result = {
        'success': False,
        'content': None,
        'error': None,
        'word_count': 0
    }
    
    for attempt in range(max_retries):
        try:
            # Download HTML
            downloaded = trafilatura.fetch_url(url)
            
            if not downloaded:
                result['error'] = 'Failed to download page'
                continue
            
            # Extract content
            content = trafilatura.extract(
                downloaded,
                include_comments=False,
                include_tables=False,
                no_fallback=False  # Try harder to extract content
            )
            
            if content and len(content.strip()) > 100:  # Min 100 chars
                result['success'] = True
                result['content'] = content.strip()
                result['word_count'] = len(content.split())
                return result
            else:
                result['error'] = 'Empty or too short content'
                
        except requests.exceptions.Timeout:
            result['error'] = f'Timeout (attempt {attempt + 1}/{max_retries})'
        except requests.exceptions.RequestException as e:
            result['error'] = f'Network error: {str(e)[:50]}'
            break  # Don't retry network errors
        except Exception as e:
            result['error'] = f'Extraction error: {str(e)[:50]}'
            break
        
        if attempt < max_retries - 1:
            time.sleep(2)  # Wait before retry
    
    return result

print("✅ Extraction function defined")
print("Features: 3 retries, 10s timeout, min 100 chars validation")
# Out:
# ✅ Extraction function defined
# Features: 3 retries, 10s timeout, min 100 chars validation

# %%
def scrape_articles_batch(articles: List[Dict], rate_limit: float = 2.5) -> List[Dict]:
    """
    Scrape multiple articles with progress tracking
    
    Args:
        articles: List of dicts with 'id', 'link', 'title'
        rate_limit: Seconds to wait between requests
    
    Returns:
        List of dicts with scraping results
    """
    results = []
    total = len(articles)
    
    print(f"🚀 Starting batch scraping: {total} articles")
    print(f"⏱️  Rate limit: {rate_limit}s between requests\n")
    print("="*60)
    
    for i, article in enumerate(articles, 1):
        print(f"\n[{i}/{total}] Scraping: {article['title'][:50]}...")
        print(f"URL: {article['link'][:60]}...")
        
        # Extract content
        extraction = extract_article_content(article['link'])
        
        # Store result
        result = {
            'id': article['id'],
            'title': article['title'],
            'link': article['link'],
            'source': article['source'],
            'success': extraction['success'],
            'content': extraction['content'],
            'word_count': extraction['word_count'],
            'error': extraction['error']
        }
        results.append(result)
        
        # Progress indicator
        if extraction['success']:
            print(f"✅ Success! Extracted {extraction['word_count']} words")
        else:
            print(f"❌ Failed: {extraction['error']}")
        
        # Rate limiting (skip on last article)
        if i < total:
            time.sleep(rate_limit)
    
    print("\n" + "="*60)
    print("✅ Batch scraping complete!")
    
    return results

print("✅ Batch scraper function defined")
# Out:
# ✅ Batch scraper function defined

# %%
# Run scraping on test batch
print(f"⚠️  About to scrape {len(test_batch)} articles")
print(f"Estimated time: ~{len(test_batch) * 2.5 / 60:.1f} minutes\n")

# Start scraping
scraping_results = scrape_articles_batch(test_batch, rate_limit=2.5)
# Out:
# ⚠️  About to scrape 10 articles
# Estimated time: ~0.4 minutes
#
# 🚀 Starting batch scraping: 10 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/10] Scraping: Mother kills child, ends life in Erode...
# URL: https://www.thehindu.com/news/cities/Coimbatore/mother-kills...
# ✅ Success! Extracted 204 words
#
# [2/10] Scraping: Bar employee arrested for murdering Salem native n...
# URL: https://www.thehindu.com/news/cities/Coimbatore/bar-employee...
# ✅ Success! Extracted 292 words
#
# [3/10] Scraping: UGD charges to be collected as per 2023 bylaw, say...
# URL: https://www.thehindu.com/news/cities/Coimbatore/ugd-charges-...
# ✅ Success! Extracted 349 words
#
# [4/10] Scraping: Coimbatore Corporation Council passes resolution t...
# URL: https://www.thehindu.com/news/cities/Coimbatore/coimbatore-c...
# ✅ Success! Extracted 378 words
#
# [5/10] Scraping: Stalin inaugurates new classrooms built at a cost ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/stalin-ina...
# ✅ Success! Extracted 85 words
#
# [6/10] Scraping: Water level in Papanasam dam stands at 135.20 feet...
# URL: https://www.thehindu.com/news/cities/Madurai/water-level-in-...
# ✅ Success! Extracted 64 words
#
# [7/10] Scraping: District-level agricultural machinery maintenance ...
# URL: https://www.thehindu.com/news/cities/Madurai/district-level-...
# ✅ Success! Extracted 200 words
#
# [8/10] Scraping: Couple killed as container lorry runs over them on...
# URL: https://www.thehindu.com/news/national/tamil-nadu/couple-kil...
# ✅ Success! Extracted 235 words
#
# [9/10] Scraping: Residents flag dumping of waste near waterbody on ...
# URL: https://www.thehindu.com/news/cities/Madurai/residents-flag-...
# ✅ Success! Extracted 339 words
#
# [10/10] Scraping: Residents of Rakkiapalayam in Tiruppur allege thef...
# URL: https://www.thehindu.com/news/cities/Coimbatore/residents-of...
# ✅ Success! Extracted 112 words
#
# ============================================================
# ✅ Batch scraping complete!

# %%
# Analyze scraping results
df_results = pd.DataFrame(scraping_results)

success_count = df_results['success'].sum()
failure_count = len(df_results) - success_count
success_rate = (success_count / len(df_results)) * 100

print("="*60)
print("📊 SCRAPING RESULTS SUMMARY")
print("="*60)
print(f"Total Attempted: {len(df_results)}")
print(f"Successful: {success_count} ({success_rate:.1f}%)")
print(f"Failed: {failure_count} ({100-success_rate:.1f}%)\n")

# Success by source
print("Success Rate by Source:")
source_success = df_results.groupby('source')['success'].agg(['sum', 'count'])
source_success['rate'] = (source_success['sum'] / source_success['count'] * 100).round(1)
for source, row in source_success.iterrows():
    print(f"  {source}: {row['sum']}/{row['count']} ({row['rate']}%)")

# Word count statistics (for successful extractions)
successful_df = df_results[df_results['success'] == True]
if len(successful_df) > 0:
    print(f"\nWord Count Statistics:")
    print(f"  Average: {successful_df['word_count'].mean():.0f} words")
    print(f"  Median: {successful_df['word_count'].median():.0f} words")
    print(f"  Min: {successful_df['word_count'].min()} words")
    print(f"  Max: {successful_df['word_count'].max()} words")

# Error breakdown
if failure_count > 0:
    print(f"\nError Breakdown:")
    error_counts = df_results[df_results['success'] == False]['error'].value_counts()
    for error, count in error_counts.items():
        print(f"  {error}: {count}")
# Out:
# ============================================================
# 📊 SCRAPING RESULTS SUMMARY
# ============================================================
# Total Attempted: 10
# Successful: 10 (100.0%)
# Failed: 0 (0.0%)
#
# Success Rate by Source:
#   The Hindu - Archive: 10.0/10.0 (100.0%)
#
# Word Count Statistics:
#   Average: 226 words
#   Median: 220 words
#   Min: 64 words
#   Max: 378 words

# %%
# Inspect sample extractions
print("="*60)
print("📰 SAMPLE EXTRACTED CONTENT")
print("="*60)

successful_samples = df_results[df_results['success'] == True].head(3)

for i, row in successful_samples.iterrows():
    print(f"\n{i+1}. {row['title'][:60]}...")
    print(f"   Source: {row['source']}")
    print(f"   Words: {row['word_count']}")
    print(f"   Content Preview:")
    print("-"*60)
    print(row['content'][:300] + "...")
    print("-"*60)
# Out:
# ============================================================
# 📰 SAMPLE EXTRACTED CONTENT
# ============================================================
#
# 1. Mother kills child, ends life in Erode...
#    Source: The Hindu - Archive
#    Words: 204
#    Content Preview:
# ------------------------------------------------------------
# In a tragic incident, a 28-year-old mother reportedly killed her one-and-a-half-year-old son and ended her life in Vellode near here on Friday.
# Police said Kavin Prasad and his wife Amaravathi had been married for five years and had a son named Aathiran. Kavin works at a private company in Perundura...
# ------------------------------------------------------------
#
# 2. Bar employee arrested for murdering Salem native near Coimba...
#    Source: The Hindu - Archive
#    Words: 292
#    Content Preview:
# ------------------------------------------------------------
# The police have arrested an employee of a bar attached to a Tasmac outlet near Sulur in Coimbatore district on charge of murdering a Salem native on June 22.
# M. Dharmar, 27, a native of Thiruvadanai in Ramanathapuram district, was arrested on Thursday for murdering K. Kavinraj, 25, of Kaveripuram ne...
# ------------------------------------------------------------
#
# 3. UGD charges to be collected as per 2023 bylaw, says Coimbato...
#    Source: The Hindu - Archive
#    Words: 349
#    Content Preview:
# ------------------------------------------------------------
# Coimbatore Corporation will collect underground drainage (UGD) charges as per the bylaw passed in 2023, and the recently revised rates will not be implemented, Corporation Commissioner M. Sivaguru Prabakaran said during the Council meeting on Thursday.
# Councillors opposed the proposed 3% annual hike...
# ------------------------------------------------------------

# %% [markdown]
# ## Phase 4: Update Database

# %%
def update_articles_in_db(results: List[Dict]) -> Dict:
    """
    Update Supabase with scraped content
    
    Returns:
        Dict with update statistics
    """
    updated = 0
    failed_updates = 0
    
    print("🔄 Updating database...\n")
    
    for result in results:
        if result['success']:
            try:
                # Update record
                supabase.table('news_cleaned').update({
                    'content_full': result['content'],
                    'needs_full_scrape': False
                }).eq('id', result['id']).execute()
                
                updated += 1
                print(f"✅ Updated: {result['title'][:50]}...")
                
            except Exception as e:
                failed_updates += 1
                print(f"❌ Failed to update {result['id']}: {e}")
    
    return {
        'updated': updated,
        'failed': failed_updates
    }

print("✅ Update function defined")
# Out:
# ✅ Update function defined

# %%
# Update database with successful extractions
print(f"⚠️  About to update {success_count} records in database\n")
print("="*60)

update_stats = update_articles_in_db(scraping_results)

print("\n" + "="*60)
print("📊 UPDATE SUMMARY")
print("="*60)
print(f"Successfully Updated: {update_stats['updated']}")
print(f"Failed Updates: {update_stats['failed']}")
# Out:
# ⚠️  About to update 10 records in database
#
# ============================================================
# 🔄 Updating database...
#
# ✅ Updated: Mother kills child, ends life in Erode...
# ✅ Updated: Bar employee arrested for murdering Salem native n...
# ✅ Updated: UGD charges to be collected as per 2023 bylaw, say...
# ✅ Updated: Coimbatore Corporation Council passes resolution t...
# ✅ Updated: Stalin inaugurates new classrooms built at a cost ...
# ✅ Updated: Water level in Papanasam dam stands at 135.20 feet...
# ✅ Updated: District-level agricultural machinery maintenance ...
# ✅ Updated: Couple killed as container lorry runs over them on...
# ✅ Updated: Residents flag dumping of waste near waterbody on ...
# ✅ Updated: Residents of Rakkiapalayam in Tiruppur allege thef...
#
# ============================================================
# 📊 UPDATE SUMMARY
# ============================================================
# Successfully Updated: 10
# Failed Updates: 0

# %%
# Verify updates in database
print("🔍 Verifying database updates...\n")

# Check total articles still needing scraping
remaining = supabase.table('news_cleaned').select('*', count='exact').eq('needs_full_scrape', True).execute()

# Check articles with content
with_content = supabase.table('news_cleaned').select('*', count='exact').not_.is_('content_full', 'null').execute()

print("="*60)
print("📊 DATABASE STATUS")
print("="*60)
print(f"Articles still needing scraping: {remaining.count}")
print(f"Articles with full content: {with_content.count}")
print(f"\n✅ Reduction: {82 - remaining.count} articles scraped from original 82")
# Out:
# 🔍 Verifying database updates...
#
# ============================================================
# 📊 DATABASE STATUS
# ============================================================
# Articles still needing scraping: 452
# Articles with full content: 2292
#
# ✅ Reduction: -370 articles scraped from original 82

# %% [markdown]
# ## Phase 5: Export Failed Articles & Full Batch Processing

# %%
# Export failed articles for investigation
failed_df = df_results[df_results['success'] == False][['title', 'link', 'source', 'error']]

if len(failed_df) > 0:
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    filename = f"../data/raw/failed_scrapes_{timestamp}.csv"
    failed_df.to_csv(filename, index=False)
    print(f"📁 Exported {len(failed_df)} failed articles to: {filename}")
else:
    print("✅ No failed articles to export!")
# Out:
# ✅ No failed articles to export!

# %%
# OPTIONAL: Process all remaining articles
# ⚠️  Uncomment and run this cell ONLY after validating test batch results

print("⚠️  PROCESSING ALL REMAINING ARTICLES")
print(f"This will scrape ~{remaining.count} articles")
print(f"Estimated time: ~{remaining.count * 2.5 / 60:.1f} minutes\n")

# Fetch all remaining articles
remaining_articles = supabase.table('news_cleaned') \
    .select('id, title, link, source, category') \
    .eq('needs_full_scrape', True) \
    .execute()

# Scrape in batches of 20
batch_size = 20
all_results = []

for i in range(0, len(remaining_articles.data), batch_size):
    batch = remaining_articles.data[i:i+batch_size]
    print(f"\n🔄 Processing batch {i//batch_size + 1}...")
    batch_results = scrape_articles_batch(batch)
    update_articles_in_db(batch_results)
    all_results.extend(batch_results)
    time.sleep(5)  # Pause between batches

print("\n✅ All articles processed!")

# print("💡 Uncomment this cell to process all remaining articles after test validation")
# Out:
# ⚠️  PROCESSING ALL REMAINING ARTICLES
# This will scrape ~452 articles
# Estimated time: ~18.8 minutes
#
#
# 🔄 Processing batch 1...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Inflow into Mettur Dam increases to 80,984 cusecs;...
# URL: https://www.thehindu.com/news/cities/Coimbatore/inflow-into-...
# ✅ Success! Extracted 310 words
#
# [2/20] Scraping: Water level in Mullaperiyar dam stands at 135.60 f...
# URL: https://www.thehindu.com/news/cities/Madurai/water-level-in-...
# ✅ Success! Extracted 98 words
#
# [3/20] Scraping: Steady Krishna water inflow to boost storage in Ch...
# URL: https://www.thehindu.com/news/cities/chennai/steady-krishna-...
# ✅ Success! Extracted 321 words
#
# [4/20] Scraping: Free Wi-Fi now available for international passeng...
# URL: https://www.thehindu.com/news/cities/chennai/free-wifi-now-a...
# ✅ Success! Extracted 156 words
#
# [5/20] Scraping: Research finds financial inclusion to be crucial f...
# URL: https://www.thehindu.com/news/national/tamil-nadu/research-f...
# ✅ Success! Extracted 528 words
#
# [6/20] Scraping: Prashanth Hospitals completes 500 robotic knee sur...
# URL: https://www.thehindu.com/news/national/tamil-nadu/prashanth-...
# ✅ Success! Extracted 209 words
#
# [7/20] Scraping: Panneerselvam urges Central government against inc...
# URL: https://www.thehindu.com/news/national/tamil-nadu/panneersel...
# ✅ Success! Extracted 122 words
#
# [8/20] Scraping: Trifurcation of Sub-Registrar Office in Thiruporur...
# URL: https://www.thehindu.com/news/cities/chennai/trifurcation-of...
# ✅ Success! Extracted 406 words
#
# [9/20] Scraping: Muslim doctor from Kashmir Valley forgoes DNB seat...
# URL: https://www.thehindu.com/news/cities/Coimbatore/kashmiri-mus...
# ✅ Success! Extracted 530 words
#
# [10/20] Scraping: ‘Fake spirituality’ of BJP will not work in Tamil ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/fake-spiri...
# ✅ Success! Extracted 389 words
#
# [11/20] Scraping: Cyber Crime Police book case against Madurai Adhee...
# URL: https://www.thehindu.com/news/cities/chennai/cyber-crime-pol...
# ✅ Success! Extracted 137 words
#
# [12/20] Scraping: Will never give up Anna for he is in our blood, sa...
# URL: https://www.thehindu.com/news/national/tamil-nadu/will-never...
# ✅ Success! Extracted 306 words
#
# [13/20] Scraping: Traffic diversion for Friday night at Goripalayam ...
# URL: https://www.thehindu.com/news/cities/Madurai/traffic-diversi...
# ✅ Success! Extracted 127 words
#
# [14/20] Scraping: Autorickshaw drivers booked for extortion in Coimb...
# URL: https://www.thehindu.com/news/cities/Coimbatore/autorickshaw...
# ✅ Success! Extracted 360 words
#
# [15/20] Scraping: The world of MCA has changed a lot: Palanivel Thia...
# URL: https://www.thehindu.com/news/national/tamil-nadu/the-world-...
# ✅ Success! Extracted 131 words
#
# [16/20] Scraping: Indo-Israel Agricultural Project helping farmers t...
# URL: https://www.thehindu.com/news/cities/Madurai/indo-israel-agr...
# ✅ Success! Extracted 564 words
#
# [17/20] Scraping: Tamil Nadu engineering college admission rank list...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tamil-nadu...
# ✅ Success! Extracted 428 words
#
# [18/20] Scraping: MLA ‘Poovai’ Jagan Moorthy must be arrested and su...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tn-mla-poo...
# ✅ Success! Extracted 762 words
#
# [19/20] Scraping: Lord Murugan conference: AIADMK ‘remained silent’ ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/lord-murug...
# ✅ Success! Extracted 301 words
#
# [20/20] Scraping: Death anniversary of India’s first Field Marshall ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/death-annive...
# ✅ Success! Extracted 246 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Inflow into Mettur Dam increases to 80,984 cusecs;...
# ✅ Updated: Water level in Mullaperiyar dam stands at 135.60 f...
# ✅ Updated: Steady Krishna water inflow to boost storage in Ch...
# ✅ Updated: Free Wi-Fi now available for international passeng...
# ✅ Updated: Research finds financial inclusion to be crucial f...
# ✅ Updated: Prashanth Hospitals completes 500 robotic knee sur...
# ✅ Updated: Panneerselvam urges Central government against inc...
# ✅ Updated: Trifurcation of Sub-Registrar Office in Thiruporur...
# ✅ Updated: Muslim doctor from Kashmir Valley forgoes DNB seat...
# ✅ Updated: ‘Fake spirituality’ of BJP will not work in Tamil ...
# ✅ Updated: Cyber Crime Police book case against Madurai Adhee...
# ✅ Updated: Will never give up Anna for he is in our blood, sa...
# ✅ Updated: Traffic diversion for Friday night at Goripalayam ...
# ✅ Updated: Autorickshaw drivers booked for extortion in Coimb...
# ✅ Updated: The world of MCA has changed a lot: Palanivel Thia...
# ✅ Updated: Indo-Israel Agricultural Project helping farmers t...
# ✅ Updated: Tamil Nadu engineering college admission rank list...
# ✅ Updated: MLA ‘Poovai’ Jagan Moorthy must be arrested and su...
# ✅ Updated: Lord Murugan conference: AIADMK ‘remained silent’ ...
# ✅ Updated: Death anniversary of India’s first Field Marshall ...
#
# 🔄 Processing batch 2...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Coimbatore MSMEs see orders moving to other distri...
# URL: https://www.thehindu.com/news/cities/Coimbatore/coimbatore-m...
# ✅ Success! Extracted 358 words
#
# [2/20] Scraping: Widespread showers lash Kanniyakumari district...
# URL: https://www.thehindu.com/news/cities/Madurai/widespread-show...
# ✅ Success! Extracted 205 words
#
# [3/20] Scraping: AIADMK to stage demonstration in Tiruvarur demandi...
# URL: https://www.thehindu.com/news/national/tamil-nadu/aiadmk-to-...
# ✅ Success! Extracted 127 words
#
# [4/20] Scraping: Nurses stage protest seeking regularisation of ser...
# URL: https://www.thehindu.com/news/cities/chennai/nurses-stage-pr...
# ✅ Success! Extracted 314 words
#
# [5/20] Scraping: Consolidated pay workers, daily wage labourers of ...
# URL: https://www.thehindu.com/news/cities/Madurai/consolidated-pa...
# ✅ Success! Extracted 340 words
#
# [6/20] Scraping: VIT Chancellor calls on Chief Minister Stalin in V...
# URL: https://www.thehindu.com/news/national/tamil-nadu/vit-chance...
# ✅ Success! Extracted 75 words
#
# [7/20] Scraping: Detailed action plan to prevent illegal sand minin...
# URL: https://www.thehindu.com/news/cities/Madurai/detailed-action...
# ✅ Success! Extracted 234 words
#
# [8/20] Scraping: Minsiter Mano Thangaraj stresses drug-free living ...
# URL: https://www.thehindu.com/news/cities/Madurai/minsiter-mano-t...
# ✅ Success! Extracted 237 words
#
# [9/20] Scraping: Thoothukudi farmers urge extension of pulse procur...
# URL: https://www.thehindu.com/news/cities/Madurai/thoothukudi-far...
# ✅ Success! Extracted 414 words
#
# [10/20] Scraping: Two detained under Goondas Act...
# URL: https://www.thehindu.com/news/cities/Madurai/two-detained-un...
# ✅ Success! Extracted 142 words
#
# [11/20] Scraping: Credit plan for Tirunelveli released: Farm sector ...
# URL: https://www.thehindu.com/news/cities/Madurai/credit-plan-for...
# ✅ Success! Extracted 161 words
#
# [12/20] Scraping: Students injured as van hits mini bus...
# URL: https://www.thehindu.com/news/cities/Madurai/students-injure...
# ✅ Success! Extracted 111 words
#
# [13/20] Scraping: Water discharge from Mettur Dam increases...
# URL: https://www.thehindu.com/news/cities/Coimbatore/water-discha...
# ✅ Success! Extracted 258 words
#
# [14/20] Scraping: NGT permits felling of 1,819 trees for widening of...
# URL: https://www.thehindu.com/news/national/tamil-nadu/ngt-permit...
# ✅ Success! Extracted 373 words
#
# [15/20] Scraping: Police on the lookout for two persons in Hindu Mun...
# URL: https://www.thehindu.com/news/cities/Coimbatore/police-on-th...
# ✅ Success! Extracted 87 words
#
# [16/20] Scraping: Waste accumulation in Chokkikulam channel irks res...
# URL: https://www.thehindu.com/news/cities/Madurai/waste-accumulat...
# ✅ Success! Extracted 311 words
#
# [17/20] Scraping: Work on three new bridges across river Varattaru b...
# URL: https://www.thehindu.com/news/cities/Coimbatore/work-on-thre...
# ✅ Success! Extracted 341 words
#
# [18/20] Scraping: Miscreants attempt to set teacher on fire in Tirup...
# URL: https://www.thehindu.com/news/cities/Coimbatore/miscreants-a...
# ✅ Success! Extracted 88 words
#
# [19/20] Scraping: Water level in Mullaperiyar dam stands at 133.65 f...
# URL: https://www.thehindu.com/news/cities/Madurai/water-level-in-...
# ✅ Success! Extracted 113 words
#
# [20/20] Scraping: Girl students from two schools in Tiruppur clash o...
# URL: https://www.thehindu.com/news/cities/Coimbatore/girl-student...
# ✅ Success! Extracted 203 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Coimbatore MSMEs see orders moving to other distri...
# ✅ Updated: Widespread showers lash Kanniyakumari district...
# ✅ Updated: AIADMK to stage demonstration in Tiruvarur demandi...
# ✅ Updated: Nurses stage protest seeking regularisation of ser...
# ✅ Updated: Consolidated pay workers, daily wage labourers of ...
# ✅ Updated: VIT Chancellor calls on Chief Minister Stalin in V...
# ✅ Updated: Detailed action plan to prevent illegal sand minin...
# ✅ Updated: Minsiter Mano Thangaraj stresses drug-free living ...
# ✅ Updated: Thoothukudi farmers urge extension of pulse procur...
# ✅ Updated: Two detained under Goondas Act...
# ✅ Updated: Credit plan for Tirunelveli released: Farm sector ...
# ✅ Updated: Students injured as van hits mini bus...
# ✅ Updated: Water discharge from Mettur Dam increases...
# ✅ Updated: NGT permits felling of 1,819 trees for widening of...
# ✅ Updated: Police on the lookout for two persons in Hindu Mun...
# ✅ Updated: Waste accumulation in Chokkikulam channel irks res...
# ✅ Updated: Work on three new bridges across river Varattaru b...
# ✅ Updated: Miscreants attempt to set teacher on fire in Tirup...
# ✅ Updated: Water level in Mullaperiyar dam stands at 133.65 f...
# ✅ Updated: Girl students from two schools in Tiruppur clash o...
#
# 🔄 Processing batch 3...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Income Tax Department conducts outreach programme ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/income-tax-d...
# ✅ Success! Extracted 163 words
#
# [2/20] Scraping: Stock exchange with a difference: how members of a...
# URL: https://www.thehindu.com/news/cities/chennai/stock-exchange-...
# ✅ Success! Extracted 939 words
#
# [3/20] Scraping: Coimbatore Passport officials recognised for servi...
# URL: https://www.thehindu.com/news/cities/Coimbatore/coimbatore-p...
# ✅ Success! Extracted 101 words
#
# [4/20] Scraping: Two arrested for peddling pseudoephedrine in Chenn...
# URL: https://www.thehindu.com/news/cities/chennai/two-arrested-fo...
# ✅ Success! Extracted 163 words
#
# [5/20] Scraping: M.G.R.’s aide Mahalingam dies at 73...
# URL: https://www.thehindu.com/news/national/tamil-nadu/mgrs-aide-...
# ✅ Success! Extracted 166 words
#
# [6/20] Scraping: Palaniswami is NDA’s chief ministerial candidate f...
# URL: https://www.thehindu.com/news/national/tamil-nadu/palaniswam...
# ✅ Success! Extracted 329 words
#
# [7/20] Scraping: Man kills daughter for wanting to marry against fa...
# URL: https://www.thehindu.com/news/national/tamil-nadu/man-kills-...
# ✅ Success! Extracted 117 words
#
# [8/20] Scraping: Former police inspector gets five years of rigorou...
# URL: https://www.thehindu.com/news/cities/chennai/former-police-i...
# ✅ Success! Extracted 219 words
#
# [9/20] Scraping: Quick action by railway official averts collision ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/quick-acti...
# ✅ Success! Extracted 841 words
#
# [10/20] Scraping: 90 members elected to town vending committees in C...
# URL: https://www.thehindu.com/news/cities/chennai/90-members-elec...
# ✅ Success! Extracted 202 words
#
# [11/20] Scraping: T.N. Village Health Nurses demand filling up of va...
# URL: https://www.thehindu.com/news/national/tamil-nadu/village-he...
# ✅ Success! Extracted 367 words
#
# [12/20] Scraping: Chennai police constable clings to moving car whil...
# URL: https://www.thehindu.com/news/national/tamil-nadu/chennai-po...
# ✅ Success! Extracted 208 words
#
# [13/20] Scraping: Chepauk Super Gillies’ owner moves Madras High Cou...
# URL: https://www.thehindu.com/news/national/tamil-nadu/chepauk-su...
# ✅ Success! Extracted 471 words
#
# [14/20] Scraping: NCW takes suo motu cognisance of sexual harassment...
# URL: https://www.thehindu.com/news/national/tamil-nadu/ncw-takes-...
# ✅ Success! Extracted 202 words
#
# [15/20] Scraping: Here’s why Gen Z finds comfort in podcasts...
# URL: https://www.thehindu.com/news/cities/chennai/heres-why-gen-z...
# ✅ Success! Extracted 512 words
#
# [16/20] Scraping: Steps being taken to ensure cotton farmers get app...
# URL: https://www.thehindu.com/news/national/tamil-nadu/steps-bein...
# ✅ Success! Extracted 143 words
#
# [17/20] Scraping: Palaniswami to begin tour of Tamil Nadu on July 7 ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/palaniswam...
# ✅ Success! Extracted 139 words
#
# [18/20] Scraping: Residents upset over drains being constructed with...
# URL: https://www.thehindu.com/news/national/tamil-nadu/residents-...
# ✅ Success! Extracted 221 words
#
# [19/20] Scraping: Weaver murdered by his relative near Cheyyar...
# URL: https://www.thehindu.com/news/national/tamil-nadu/weaver-mur...
# ✅ Success! Extracted 186 words
#
# [20/20] Scraping: Stray dog ‘Tiger’ earns kudos for helping catch a ...
# URL: https://www.thehindu.com/news/cities/chennai/stray-dog-tiger...
# ✅ Success! Extracted 148 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Income Tax Department conducts outreach programme ...
# ✅ Updated: Stock exchange with a difference: how members of a...
# ✅ Updated: Coimbatore Passport officials recognised for servi...
# ✅ Updated: Two arrested for peddling pseudoephedrine in Chenn...
# ✅ Updated: M.G.R.’s aide Mahalingam dies at 73...
# ✅ Updated: Palaniswami is NDA’s chief ministerial candidate f...
# ✅ Updated: Man kills daughter for wanting to marry against fa...
# ✅ Updated: Former police inspector gets five years of rigorou...
# ✅ Updated: Quick action by railway official averts collision ...
# ✅ Updated: 90 members elected to town vending committees in C...
# ✅ Updated: T.N. Village Health Nurses demand filling up of va...
# ✅ Updated: Chennai police constable clings to moving car whil...
# ✅ Updated: Chepauk Super Gillies’ owner moves Madras High Cou...
# ✅ Updated: NCW takes suo motu cognisance of sexual harassment...
# ✅ Updated: Here’s why Gen Z finds comfort in podcasts...
# ✅ Updated: Steps being taken to ensure cotton farmers get app...
# ✅ Updated: Palaniswami to begin tour of Tamil Nadu on July 7 ...
# ✅ Updated: Residents upset over drains being constructed with...
# ✅ Updated: Weaver murdered by his relative near Cheyyar...
# ✅ Updated: Stray dog ‘Tiger’ earns kudos for helping catch a ...
#
# 🔄 Processing batch 4...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Police constable, his friend arrested for cheating...
# URL: https://www.thehindu.com/news/cities/chennai/police-constabl...
# ✅ Success! Extracted 172 words
#
# [2/20] Scraping: TNCC president calling on Ramadoss fuels speculati...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tncc-presi...
# ✅ Success! Extracted 531 words
#
# [3/20] Scraping: IIT-Madras’ Zanzibar campus launches UG course in ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/iit-madras...
# ✅ Success! Extracted 275 words
#
# [4/20] Scraping: Youth held for attacking bus driver...
# URL: https://www.thehindu.com/news/cities/chennai/youth-held-for-...
# ✅ Success! Extracted 140 words
#
# [5/20] Scraping: Chennai Metrowater steps up sewer maintenance with...
# URL: https://www.thehindu.com/news/cities/chennai/chennai-metrowa...
# ✅ Success! Extracted 498 words
#
# [6/20] Scraping: TNEA toppers prefer Computer Science Engineering...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tnea-toppe...
# ✅ Success! Extracted 533 words
#
# [7/20] Scraping: Long queues at parking lots of Chennai Metro Rail ...
# URL: https://www.thehindu.com/news/cities/chennai/longer-waiting-...
# ✅ Success! Extracted 279 words
#
# [8/20] Scraping: 24 ‘registered unrecognised political parties’ und...
# URL: https://www.thehindu.com/news/national/tamil-nadu/24-registe...
# ✅ Success! Extracted 249 words
#
# [9/20] Scraping: MEMU train derails near Arakkonam...
# URL: https://www.thehindu.com/news/cities/chennai/memu-train-dera...
# ✅ Success! Extracted 126 words
#
# [10/20] Scraping: Cyber Crime Police bust call centre defrauding man...
# URL: https://www.thehindu.com/news/cities/chennai/cyber-crime-pol...
# ✅ Success! Extracted 325 words
#
# [11/20] Scraping: Traffic Diversion near RBI Subway...
# URL: https://www.thehindu.com/news/cities/chennai/traffic-diversi...
# ✅ Success! Extracted 107 words
#
# [12/20] Scraping: Vaiko condemns RSS general secretary’s call for re...
# URL: https://www.thehindu.com/news/national/tamil-nadu/vaiko-cond...
# ✅ Success! Extracted 219 words
#
# [13/20] Scraping: Tamil Nadu regains 39 super speciality medical sea...
# URL: https://www.thehindu.com/news/cities/chennai/tn-gets-back-39...
# ✅ Success! Extracted 373 words
#
# [14/20] Scraping: Most govt. arts colleges administered by In-Charge...
# URL: https://www.thehindu.com/news/cities/Coimbatore/most-govt-ar...
# ✅ Success! Extracted 329 words
#
# [15/20] Scraping: Competition heats up for TNEA 2025 as more student...
# URL: https://www.thehindu.com/news/national/tamil-nadu/competitio...
# ✅ Success! Extracted 345 words
#
# [16/20] Scraping: Murugan Bhakthargal conference held as a political...
# URL: https://www.thehindu.com/news/national/tamil-nadu/murugan-bh...
# ✅ Success! Extracted 363 words
#
# [17/20] Scraping: Implementation of government schemes reviewed at D...
# URL: https://www.thehindu.com/news/cities/Madurai/implementation-...
# ✅ Success! Extracted 323 words
#
# [18/20] Scraping: ‘Maternity period has to be counted as part of bon...
# URL: https://www.thehindu.com/news/cities/Madurai/maternity-perio...
# ✅ Success! Extracted 458 words
#
# [19/20] Scraping: Madurai DPO gets automated external defibrillator ...
# URL: https://www.thehindu.com/news/cities/Madurai/madurai-dpo-get...
# ✅ Success! Extracted 126 words
#
# [20/20] Scraping: Release stipulated quota of 31 tmc ft. of Cauvery ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/release-st...
# ✅ Success! Extracted 136 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Police constable, his friend arrested for cheating...
# ✅ Updated: TNCC president calling on Ramadoss fuels speculati...
# ✅ Updated: IIT-Madras’ Zanzibar campus launches UG course in ...
# ✅ Updated: Youth held for attacking bus driver...
# ✅ Updated: Chennai Metrowater steps up sewer maintenance with...
# ✅ Updated: TNEA toppers prefer Computer Science Engineering...
# ✅ Updated: Long queues at parking lots of Chennai Metro Rail ...
# ✅ Updated: 24 ‘registered unrecognised political parties’ und...
# ✅ Updated: MEMU train derails near Arakkonam...
# ✅ Updated: Cyber Crime Police bust call centre defrauding man...
# ✅ Updated: Traffic Diversion near RBI Subway...
# ✅ Updated: Vaiko condemns RSS general secretary’s call for re...
# ✅ Updated: Tamil Nadu regains 39 super speciality medical sea...
# ✅ Updated: Most govt. arts colleges administered by In-Charge...
# ✅ Updated: Competition heats up for TNEA 2025 as more student...
# ✅ Updated: Murugan Bhakthargal conference held as a political...
# ✅ Updated: Implementation of government schemes reviewed at D...
# ✅ Updated: ‘Maternity period has to be counted as part of bon...
# ✅ Updated: Madurai DPO gets automated external defibrillator ...
# ✅ Updated: Release stipulated quota of 31 tmc ft. of Cauvery ...
#
# 🔄 Processing batch 5...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Cage kept to capture stray bear...
# URL: https://www.thehindu.com/news/cities/Madurai/cage-kept-to-ca...
# ✅ Success! Extracted 127 words
#
# [2/20] Scraping: Round the clock student help desk set up at Thooth...
# URL: https://www.thehindu.com/news/cities/Madurai/round-the-clock...
# ✅ Success! Extracted 466 words
#
# [3/20] Scraping: Corporation workers siphon off money using loophol...
# URL: https://www.thehindu.com/news/cities/Madurai/corporation-wor...
# ✅ Success! Extracted 326 words
#
# [4/20] Scraping: Farmers plan large-scale participation in hunger s...
# URL: https://www.thehindu.com/news/cities/Coimbatore/farmers-plan...
# ✅ Success! Extracted 260 words
#
# [5/20] Scraping: Farmers seek monetary assistance for crops damage...
# URL: https://www.thehindu.com/news/cities/Madurai/farmers-seek-mo...
# ✅ Success! Extracted 213 words
#
# [6/20] Scraping: Sivaganga collector K. Porkodi assumes office...
# URL: https://www.thehindu.com/news/cities/Madurai/sivaganga-colle...
# ✅ Success! Extracted 223 words
#
# [7/20] Scraping: Coimbatore city cybercrime police recover ₹2 crore...
# URL: https://www.thehindu.com/news/cities/Coimbatore/coimbatore-c...
# ✅ Success! Extracted 181 words
#
# [8/20] Scraping: ‘Prevent footboard travel in buses’...
# URL: https://www.thehindu.com/news/cities/Madurai/prevent-footboa...
# ✅ Success! Extracted 111 words
#
# [9/20] Scraping: MUFA appeals for replacement of MKU Registrar (in-...
# URL: https://www.thehindu.com/news/cities/Madurai/mufa-appeals-fo...
# ✅ Success! Extracted 133 words
#
# [10/20] Scraping: AIADMK councillors walk out from Salem Corporation...
# URL: https://www.thehindu.com/news/cities/Coimbatore/aiadmk-counc...
# ✅ Success! Extracted 437 words
#
# [11/20] Scraping: Viral social media post attracts scores of tourist...
# URL: https://www.thehindu.com/news/cities/Madurai/viral-social-me...
# ✅ Success! Extracted 295 words
#
# [12/20] Scraping: Residents protest against delay in widening of sto...
# URL: https://www.thehindu.com/news/national/tamil-nadu/residents-...
# ✅ Success! Extracted 288 words
#
# [13/20] Scraping: Research institute favours climate-friendly non-pu...
# URL: https://www.thehindu.com/elections/tamil-nadu-assembly/resea...
# ✅ Success! Extracted 371 words
#
# [14/20] Scraping: New Collector assumes office in Namakkal district...
# URL: https://www.thehindu.com/news/cities/Coimbatore/new-collecto...
# ✅ Success! Extracted 76 words
#
# [15/20] Scraping: Tamil Nadu State Primary Cooperative Employees Uni...
# URL: https://www.thehindu.com/news/cities/Madurai/tamil-nadu-stat...
# ✅ Success! Extracted 255 words
#
# [16/20] Scraping: Inflow into Mettur Dam increases...
# URL: https://www.thehindu.com/news/cities/Coimbatore/inflow-into-...
# ✅ Success! Extracted 205 words
#
# [17/20] Scraping: Sri Lankan govt. detains 3,550 fishermen, 706 boat...
# URL: https://www.thehindu.com/news/cities/Madurai/sri-lankan-govt...
# ✅ Success! Extracted 554 words
#
# [18/20] Scraping: Will instruct schools on water bell initiative, sa...
# URL: https://www.thehindu.com/news/cities/Coimbatore/will-instruc...
# ✅ Success! Extracted 416 words
#
# [19/20] Scraping: Tamil Nadu Assembly Speaker reaffirms HR&CE’s cont...
# URL: https://www.thehindu.com/news/cities/Madurai/tamil-nadu-asse...
# ✅ Success! Extracted 315 words
#
# [20/20] Scraping: College students take pledge against drug abuse in...
# URL: https://www.thehindu.com/news/cities/Coimbatore/college-stud...
# ✅ Success! Extracted 185 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Cage kept to capture stray bear...
# ✅ Updated: Round the clock student help desk set up at Thooth...
# ✅ Updated: Corporation workers siphon off money using loophol...
# ✅ Updated: Farmers plan large-scale participation in hunger s...
# ✅ Updated: Farmers seek monetary assistance for crops damage...
# ✅ Updated: Sivaganga collector K. Porkodi assumes office...
# ✅ Updated: Coimbatore city cybercrime police recover ₹2 crore...
# ✅ Updated: ‘Prevent footboard travel in buses’...
# ✅ Updated: MUFA appeals for replacement of MKU Registrar (in-...
# ✅ Updated: AIADMK councillors walk out from Salem Corporation...
# ✅ Updated: Viral social media post attracts scores of tourist...
# ✅ Updated: Residents protest against delay in widening of sto...
# ✅ Updated: Research institute favours climate-friendly non-pu...
# ✅ Updated: New Collector assumes office in Namakkal district...
# ✅ Updated: Tamil Nadu State Primary Cooperative Employees Uni...
# ✅ Updated: Inflow into Mettur Dam increases...
# ✅ Updated: Sri Lankan govt. detains 3,550 fishermen, 706 boat...
# ✅ Updated: Will instruct schools on water bell initiative, sa...
# ✅ Updated: Tamil Nadu Assembly Speaker reaffirms HR&CE’s cont...
# ✅ Updated: College students take pledge against drug abuse in...
#
# 🔄 Processing batch 6...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: The food delivery partner on three wheels...
# URL: https://www.thehindu.com/news/cities/chennai/the-food-delive...
# ✅ Success! Extracted 455 words
#
# [2/20] Scraping: Intern at IIT-Madras sexually harassed on campus, ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/intern-at-...
# ✅ Success! Extracted 277 words
#
# [3/20] Scraping: 17 candidates from TNAU’s Forest College and Resea...
# URL: https://www.thehindu.com/news/cities/Coimbatore/17-candidate...
# ✅ Success! Extracted 277 words
#
# [4/20] Scraping: New Collector assumes office in Erode...
# URL: https://www.thehindu.com/news/cities/Coimbatore/new-collecto...
# ✅ Success! Extracted 133 words
#
# [5/20] Scraping: NGT directs Coimbatore Corporation to clear legacy...
# URL: https://www.thehindu.com/news/cities/Coimbatore/ngt-directs-...
# ✅ Success! Extracted 233 words
#
# [6/20] Scraping: Foot and mouth disease vaccination from July 2 to ...
# URL: https://www.thehindu.com/news/cities/Madurai/foot-and-mouth-...
# ✅ Success! Extracted 219 words
#
# [7/20] Scraping: Erode native arrested for cyber fraud...
# URL: https://www.thehindu.com/news/cities/Coimbatore/erode-native...
# ✅ Success! Extracted 188 words
#
# [8/20] Scraping: Chance to get approval for unapproved housing plot...
# URL: https://www.thehindu.com/news/cities/Madurai/chance-to-get-a...
# ✅ Success! Extracted 136 words
#
# [9/20] Scraping: Welfare assistance worth ₹2.92 crore distributed t...
# URL: https://www.thehindu.com/news/cities/Coimbatore/welfare-assi...
# ✅ Success! Extracted 317 words
#
# [10/20] Scraping: NGT should constitute committee to monitor sapling...
# URL: https://www.thehindu.com/news/cities/Coimbatore/ngt-should-c...
# ✅ Success! Extracted 312 words
#
# [11/20] Scraping: Coimbatore City Police, Young Indians conduct awar...
# URL: https://www.thehindu.com/news/cities/Coimbatore/coimbatore-c...
# ✅ Success! Extracted 206 words
#
# [12/20] Scraping: Water level in Mullaperiyar dam...
# URL: https://www.thehindu.com/news/cities/Madurai/water-level-in-...
# ✅ Success! Extracted 108 words
#
# [13/20] Scraping: Water level in Papanasam, Manimuthar dams...
# URL: https://www.thehindu.com/news/cities/Madurai/water-level-in-...
# ✅ Success! Extracted 60 words
#
# [14/20] Scraping: Governor R.N. Ravi gifts autorickshaw to woman who...
# URL: https://www.thehindu.com/news/national/tamil-nadu/governor-r...
# ✅ Success! Extracted 119 words
#
# [15/20] Scraping: VIT organises debating skills programme for school...
# URL: https://www.thehindu.com/news/national/tamil-nadu/vit-organi...
# ✅ Success! Extracted 153 words
#
# [16/20] Scraping: Thoothukudi Marine police seize 2,000 kg of beedi ...
# URL: https://www.thehindu.com/news/cities/Madurai/thoothukudi-mar...
# ✅ Success! Extracted 128 words
#
# [17/20] Scraping: Collector inspects Hogenakkal...
# URL: https://www.thehindu.com/news/cities/Coimbatore/collector-in...
# ✅ Success! Extracted 133 words
#
# [18/20] Scraping: Thoothukudi Government Hospital to host medical ex...
# URL: https://www.thehindu.com/news/cities/Madurai/thoothukudi-gov...
# ✅ Success! Extracted 155 words
#
# [19/20] Scraping: After 18 years and two attempts, Chennai Port Auth...
# URL: https://www.thehindu.com/news/cities/chennai/after-18-years-...
# ✅ Success! Extracted 412 words
#
# [20/20] Scraping: 313 vehicles impounded for mining irregularities i...
# URL: https://www.thehindu.com/news/cities/Coimbatore/313-vehicles...
# ✅ Success! Extracted 272 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: The food delivery partner on three wheels...
# ✅ Updated: Intern at IIT-Madras sexually harassed on campus, ...
# ✅ Updated: 17 candidates from TNAU’s Forest College and Resea...
# ✅ Updated: New Collector assumes office in Erode...
# ✅ Updated: NGT directs Coimbatore Corporation to clear legacy...
# ✅ Updated: Foot and mouth disease vaccination from July 2 to ...
# ✅ Updated: Erode native arrested for cyber fraud...
# ✅ Updated: Chance to get approval for unapproved housing plot...
# ✅ Updated: Welfare assistance worth ₹2.92 crore distributed t...
# ✅ Updated: NGT should constitute committee to monitor sapling...
# ✅ Updated: Coimbatore City Police, Young Indians conduct awar...
# ✅ Updated: Water level in Mullaperiyar dam...
# ✅ Updated: Water level in Papanasam, Manimuthar dams...
# ✅ Updated: Governor R.N. Ravi gifts autorickshaw to woman who...
# ✅ Updated: VIT organises debating skills programme for school...
# ✅ Updated: Thoothukudi Marine police seize 2,000 kg of beedi ...
# ✅ Updated: Collector inspects Hogenakkal...
# ✅ Updated: Thoothukudi Government Hospital to host medical ex...
# ✅ Updated: After 18 years and two attempts, Chennai Port Auth...
# ✅ Updated: 313 vehicles impounded for mining irregularities i...
#
# 🔄 Processing batch 7...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Concerns raised over shortage of conservancy worke...
# URL: https://www.thehindu.com/news/cities/Coimbatore/concerns-rai...
# ✅ Success! Extracted 382 words
#
# [2/20] Scraping: HR&CE Minister inspects preparations at Tiruchendu...
# URL: https://www.thehindu.com/news/cities/Madurai/hrce-minister-i...
# ✅ Success! Extracted 278 words
#
# [3/20] Scraping: Two-day Young Indians Parliament held in Coimbator...
# URL: https://www.thehindu.com/news/cities/Coimbatore/two-day-youn...
# ✅ Success! Extracted 177 words
#
# [4/20] Scraping: Highways team inspects bridge work across Palar in...
# URL: https://www.thehindu.com/news/national/tamil-nadu/highways-t...
# ✅ Success! Extracted 448 words
#
# [5/20] Scraping: Habitual offender involved in wildlife crimes deta...
# URL: https://www.thehindu.com/news/cities/Coimbatore/habitual-off...
# ✅ Success! Extracted 208 words
#
# [6/20] Scraping: AITUC urges Erode Corporation to implement revised...
# URL: https://www.thehindu.com/news/cities/Coimbatore/aituc-urges-...
# ✅ Success! Extracted 314 words
#
# [7/20] Scraping: A trash point on OMR...
# URL: https://www.thehindu.com/news/cities/chennai/a-trash-point-o...
# ✅ Success! Extracted 244 words
#
# [8/20] Scraping: Our priority is to speed up implementation of gove...
# URL: https://www.thehindu.com/news/national/tamil-nadu/our-priori...
# ✅ Success! Extracted 269 words
#
# [9/20] Scraping: School Education Minister holds review meeting on ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/school-educa...
# ✅ Success! Extracted 200 words
#
# [10/20] Scraping: Man held for murdering wife, son in Erode...
# URL: https://www.thehindu.com/news/cities/Coimbatore/man-held-for...
# ✅ Success! Extracted 146 words
#
# [11/20] Scraping: Scope for charity on Padur Bypass Road...
# URL: https://www.thehindu.com/news/cities/chennai/scope-for-chari...
# ✅ Success! Extracted 302 words
#
# [12/20] Scraping: State will file Special Leave Petition in Supreme ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/state-will-f...
# ✅ Success! Extracted 322 words
#
# [13/20] Scraping: Revitalised Blue Flag beach at Marina to be launch...
# URL: https://www.thehindu.com/news/cities/chennai/revitalised-blu...
# ✅ Success! Extracted 269 words
#
# [14/20] Scraping: T.N. set to begin land acquisition process for Par...
# URL: https://www.thehindu.com/news/cities/chennai/tn-set-to-begin...
# ✅ Success! Extracted 308 words
#
# [15/20] Scraping: Encroachments continue to hinder pedestrian moveme...
# URL: https://www.thehindu.com/news/cities/chennai/encroachments-c...
# ✅ Success! Extracted 314 words
#
# [16/20] Scraping: Chennai’s annual self-respect rainbow Pride March ...
# URL: https://www.thehindu.com/news/cities/chennai/chennais-annual...
# ✅ Success! Extracted 303 words
#
# [17/20] Scraping: 63 statues installed, 11 manimandapams built in 4 ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/63-statues...
# ✅ Success! Extracted 248 words
#
# [18/20] Scraping: Pro-Schedule Castes organisations and activists al...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tiruppur-d...
# ✅ Success! Extracted 339 words
#
# [19/20] Scraping: More parties will join NDA in T.N; DMK-led allianc...
# URL: https://www.thehindu.com/news/national/tamil-nadu/more-parti...
# ✅ Success! Extracted 168 words
#
# [20/20] Scraping: Book on POCSO Act released in Madurai...
# URL: https://www.thehindu.com/news/cities/Madurai/book-on-pocso-a...
# ✅ Success! Extracted 283 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Concerns raised over shortage of conservancy worke...
# ✅ Updated: HR&CE Minister inspects preparations at Tiruchendu...
# ✅ Updated: Two-day Young Indians Parliament held in Coimbator...
# ✅ Updated: Highways team inspects bridge work across Palar in...
# ✅ Updated: Habitual offender involved in wildlife crimes deta...
# ✅ Updated: AITUC urges Erode Corporation to implement revised...
# ✅ Updated: A trash point on OMR...
# ✅ Updated: Our priority is to speed up implementation of gove...
# ✅ Updated: School Education Minister holds review meeting on ...
# ✅ Updated: Man held for murdering wife, son in Erode...
# ✅ Updated: Scope for charity on Padur Bypass Road...
# ✅ Updated: State will file Special Leave Petition in Supreme ...
# ✅ Updated: Revitalised Blue Flag beach at Marina to be launch...
# ✅ Updated: T.N. set to begin land acquisition process for Par...
# ✅ Updated: Encroachments continue to hinder pedestrian moveme...
# ✅ Updated: Chennai’s annual self-respect rainbow Pride March ...
# ✅ Updated: 63 statues installed, 11 manimandapams built in 4 ...
# ✅ Updated: Pro-Schedule Castes organisations and activists al...
# ✅ Updated: More parties will join NDA in T.N; DMK-led allianc...
# ✅ Updated: Book on POCSO Act released in Madurai...
#
# 🔄 Processing batch 8...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Muthupet mangrove cover increases by 2,057 hectare...
# URL: https://www.thehindu.com/news/national/tamil-nadu/muthupet-m...
# ✅ Success! Extracted 318 words
#
# [2/20] Scraping: Police seize 450 kg gutka near Vaniyambadi; one he...
# URL: https://www.thehindu.com/news/national/tamil-nadu/police-sei...
# ✅ Success! Extracted 168 words
#
# [3/20] Scraping: Cylinder blast injures two persons near Arakkonam...
# URL: https://www.thehindu.com/news/national/tamil-nadu/cylinder-b...
# ✅ Success! Extracted 194 words
#
# [4/20] Scraping: APDCL enters into agreement with NARL, joint ventu...
# URL: https://www.thehindu.com/news/national/tamil-nadu/apdcl-ente...
# ✅ Success! Extracted 330 words
#
# [5/20] Scraping: FPO conclave on empowering farmers to adopt organi...
# URL: https://www.thehindu.com/news/cities/Madurai/fpo-conclave-on...
# ✅ Success! Extracted 258 words
#
# [6/20] Scraping: Six policemen placed under suspension over the dea...
# URL: https://www.thehindu.com/news/national/tamil-nadu/six-police...
# ✅ Success! Extracted 365 words
#
# [7/20] Scraping: Health Minister inaugurates healthcare facilities ...
# URL: https://www.thehindu.com/news/cities/Madurai/health-minister...
# ✅ Success! Extracted 312 words
#
# [8/20] Scraping: Woman ends life over dowry harassment in Tiruppur...
# URL: https://www.thehindu.com/news/national/tamil-nadu/woman-foun...
# ✅ Success! Extracted 193 words
#
# [9/20] Scraping: Native trees to bring back green cover on 50 hecta...
# URL: https://www.thehindu.com/news/cities/Coimbatore/native-trees...
# ✅ Success! Extracted 193 words
#
# [10/20] Scraping: Chennai policeman goes the extra mile...
# URL: https://www.thehindu.com/news/cities/chennai/head-constable-...
# ✅ Success! Extracted 371 words
#
# [11/20] Scraping: Tribesman shot dead in forest in Coimbatore distri...
# URL: https://www.thehindu.com/news/cities/Coimbatore/tribesman-sh...
# ✅ Success! Extracted 207 words
#
# [12/20] Scraping: Contempt petition filed in Madras High Court again...
# URL: https://www.thehindu.com/news/cities/Coimbatore/contempt-pet...
# ✅ Success! Extracted 208 words
#
# [13/20] Scraping: DMK will secure majority, there will be no coaliti...
# URL: https://www.thehindu.com/news/national/tamil-nadu/dmk-will-s...
# ✅ Success! Extracted 401 words
#
# [14/20] Scraping: Valuables stolen from private school correspondent...
# URL: https://www.thehindu.com/news/cities/Madurai/valuables-stole...
# ✅ Success! Extracted 153 words
#
# [15/20] Scraping: Tamil Nadu expands Japanese Encephalitis vaccinati...
# URL: https://www.thehindu.com/news/cities/chennai/tamil-nadu-expa...
# ✅ Success! Extracted 427 words
#
# [16/20] Scraping: Applications invited for regularisation of unappro...
# URL: https://www.thehindu.com/news/cities/Madurai/applications-in...
# ✅ Success! Extracted 94 words
#
# [17/20] Scraping: Run to create awareness of evils of drugs held in ...
# URL: https://www.thehindu.com/news/cities/Madurai/run-to-create-a...
# ✅ Success! Extracted 137 words
#
# [18/20] Scraping: 1.45 lakh cows and buffaloes to be vaccinated agai...
# URL: https://www.thehindu.com/news/cities/Madurai/145-lakh-cows-a...
# ✅ Success! Extracted 320 words
#
# [19/20] Scraping: ₹98.81 lakh welfare aid distributed to differently...
# URL: https://www.thehindu.com/news/cities/Madurai/rs-9881-lakh-we...
# ✅ Success! Extracted 208 words
#
# [20/20] Scraping: Tamil Nadu commences restoration of Kariyachalli i...
# URL: https://www.thehindu.com/news/cities/Madurai/tamil-nadu-comm...
# ✅ Success! Extracted 589 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Muthupet mangrove cover increases by 2,057 hectare...
# ✅ Updated: Police seize 450 kg gutka near Vaniyambadi; one he...
# ✅ Updated: Cylinder blast injures two persons near Arakkonam...
# ✅ Updated: APDCL enters into agreement with NARL, joint ventu...
# ✅ Updated: FPO conclave on empowering farmers to adopt organi...
# ✅ Updated: Six policemen placed under suspension over the dea...
# ✅ Updated: Health Minister inaugurates healthcare facilities ...
# ✅ Updated: Woman ends life over dowry harassment in Tiruppur...
# ✅ Updated: Native trees to bring back green cover on 50 hecta...
# ✅ Updated: Chennai policeman goes the extra mile...
# ✅ Updated: Tribesman shot dead in forest in Coimbatore distri...
# ✅ Updated: Contempt petition filed in Madras High Court again...
# ✅ Updated: DMK will secure majority, there will be no coaliti...
# ✅ Updated: Valuables stolen from private school correspondent...
# ✅ Updated: Tamil Nadu expands Japanese Encephalitis vaccinati...
# ✅ Updated: Applications invited for regularisation of unappro...
# ✅ Updated: Run to create awareness of evils of drugs held in ...
# ✅ Updated: 1.45 lakh cows and buffaloes to be vaccinated agai...
# ✅ Updated: ₹98.81 lakh welfare aid distributed to differently...
# ✅ Updated: Tamil Nadu commences restoration of Kariyachalli i...
#
# 🔄 Processing batch 9...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Mettur Dam attains full capacity; Minister inspect...
# URL: https://www.thehindu.com/news/cities/Coimbatore/mettur-dam-a...
# ✅ Success! Extracted 251 words
#
# [2/20] Scraping: Head constable dies in accident in Krishnagiri...
# URL: https://www.thehindu.com/news/cities/Coimbatore/head-constab...
# ✅ Success! Extracted 253 words
#
# [3/20] Scraping: Madurai readers mail...
# URL: https://www.thehindu.com/news/cities/Madurai/madurai-readers...
# ✅ Success! Extracted 123 words
#
# [4/20] Scraping: Tamil Nadu government rejects Coimbatore Corporati...
# URL: https://www.thehindu.com/news/cities/Coimbatore/tamil-nadu-g...
# ✅ Success! Extracted 267 words
#
# [5/20] Scraping: Water level in Mullaperiyar dam stands at  136.15 ...
# URL: https://www.thehindu.com/news/cities/Madurai/water-level-in-...
# ✅ Success! Extracted 98 words
#
# [6/20] Scraping: Water level in dams and rainfall...
# URL: https://www.thehindu.com/news/cities/Madurai/water-level-in-...
# ✅ Success! Extracted 93 words
#
# [7/20] Scraping: Valparai Assembly seat declared vacant, bypoll unl...
# URL: https://www.thehindu.com/news/national/tamil-nadu/valparai-a...
# ✅ Success! Extracted 105 words
#
# [8/20] Scraping: Tirunelveli readers mail...
# URL: https://www.thehindu.com/news/cities/Madurai/tirunelveli-rea...
# ✅ Success! Extracted 360 words
#
# [9/20] Scraping: Dindigul readers mail...
# URL: https://www.thehindu.com/news/cities/Madurai/dindigul-reader...
# ✅ Success! Extracted 360 words
#
# [10/20] Scraping: Madurai Corporation calls for CSR funds for better...
# URL: https://www.thehindu.com/news/cities/Madurai/madurai-corpora...
# ✅ Success! Extracted 1047 words
#
# [11/20] Scraping: North Chennai residents, experts to propose altern...
# URL: https://www.thehindu.com/news/cities/chennai/north-chennai-r...
# ✅ Success! Extracted 708 words
#
# [12/20] Scraping: Thirumullaivoyal, a fast-developing suburb, strugg...
# URL: https://www.thehindu.com/news/cities/chennai/thirumullaivoya...
# ✅ Success! Extracted 698 words
#
# [13/20] Scraping: IIT Madras-Accenture collaborate to offer skilling...
# URL: https://www.thehindu.com/news/national/tamil-nadu/iit-madras...
# ✅ Success! Extracted 118 words
#
# [14/20] Scraping: Police launch probe into abduction of jeweller in ...
# URL: https://www.thehindu.com/news/cities/chennai/police-launch-p...
# ✅ Success! Extracted 160 words
#
# [15/20] Scraping: Tamil Nadu government to absorb the burden of the ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/state-gove...
# ✅ Success! Extracted 263 words
#
# [16/20] Scraping: Rita John, theoretical physics professor, is Madra...
# URL: https://www.thehindu.com/news/national/tamil-nadu/rita-john-...
# ✅ Success! Extracted 305 words
#
# [17/20] Scraping: A year after enforcement of new criminal laws bega...
# URL: https://www.thehindu.com/news/national/tamil-nadu/a-year-aft...
# ✅ Success! Extracted 299 words
#
# [18/20] Scraping: Stalin’s inaction has resulted in custodial deaths...
# URL: https://www.thehindu.com/news/national/tamil-nadu/stalins-in...
# ✅ Success! Extracted 275 words
#
# [19/20] Scraping: Chennai Corporation Council approves sanitation st...
# URL: https://www.thehindu.com/news/cities/chennai/chennai-corpora...
# ✅ Success! Extracted 299 words
#
# [20/20] Scraping: ‘Several government employees have encroached on G...
# URL: https://www.thehindu.com/news/cities/chennai/several-governm...
# ✅ Success! Extracted 192 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Mettur Dam attains full capacity; Minister inspect...
# ✅ Updated: Head constable dies in accident in Krishnagiri...
# ✅ Updated: Madurai readers mail...
# ✅ Updated: Tamil Nadu government rejects Coimbatore Corporati...
# ✅ Updated: Water level in Mullaperiyar dam stands at  136.15 ...
# ✅ Updated: Water level in dams and rainfall...
# ✅ Updated: Valparai Assembly seat declared vacant, bypoll unl...
# ✅ Updated: Tirunelveli readers mail...
# ✅ Updated: Dindigul readers mail...
# ✅ Updated: Madurai Corporation calls for CSR funds for better...
# ✅ Updated: North Chennai residents, experts to propose altern...
# ✅ Updated: Thirumullaivoyal, a fast-developing suburb, strugg...
# ✅ Updated: IIT Madras-Accenture collaborate to offer skilling...
# ✅ Updated: Police launch probe into abduction of jeweller in ...
# ✅ Updated: Tamil Nadu government to absorb the burden of the ...
# ✅ Updated: Rita John, theoretical physics professor, is Madra...
# ✅ Updated: A year after enforcement of new criminal laws bega...
# ✅ Updated: Stalin’s inaction has resulted in custodial deaths...
# ✅ Updated: Chennai Corporation Council approves sanitation st...
# ✅ Updated: ‘Several government employees have encroached on G...
#
# 🔄 Processing batch 10...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Five convicted in a bank fraud case...
# URL: https://www.thehindu.com/news/national/tamil-nadu/five-convi...
# ✅ Success! Extracted 224 words
#
# [2/20] Scraping: EPS lacks understanding of numbers from his own re...
# URL: https://www.thehindu.com/news/national/tamil-nadu/eps-lacks-...
# ✅ Success! Extracted 286 words
#
# [3/20] Scraping: Demonte Road to be renamed, Entertainment Tax redu...
# URL: https://www.thehindu.com/news/cities/chennai/demonte-road-to...
# ✅ Success! Extracted 201 words
#
# [4/20] Scraping: Corporation Council passes 110 resolutions for civ...
# URL: https://www.thehindu.com/news/cities/chennai/corporation-cou...
# ✅ Success! Extracted 383 words
#
# [5/20] Scraping: ASEAN-India Cruise Dialogue 2025 aimed at enhancin...
# URL: https://www.thehindu.com/news/cities/chennai/asean-india-cru...
# ✅ Success! Extracted 303 words
#
# [6/20] Scraping: Sivaganga custodial torture case: Five policemen a...
# URL: https://www.thehindu.com/news/national/tamil-nadu/sivaganga-...
# ✅ Success! Extracted 539 words
#
# [7/20] Scraping: ‘Fulfil demands of government doctors’...
# URL: https://www.thehindu.com/news/cities/chennai/fulfil-demands-...
# ✅ Success! Extracted 185 words
#
# [8/20] Scraping: Advertising Club Madras launches MADDYS 2025 award...
# URL: https://www.thehindu.com/news/cities/chennai/advertising-clu...
# ✅ Success! Extracted 234 words
#
# [9/20] Scraping: Now, 12-car EMU trains will operate on three secti...
# URL: https://www.thehindu.com/news/cities/chennai/southern-railwa...
# ✅ Success! Extracted 463 words
#
# [10/20] Scraping: NLCIL employees undertake beach clean-up drive in ...
# URL: https://www.thehindu.com/news/national/tamil-nadu/nlcil-empl...
# ✅ Success! Extracted 62 words
#
# [11/20] Scraping: Plan to cover 4.54 lakh cattle across Villupuram d...
# URL: https://www.thehindu.com/news/national/tamil-nadu/plan-to-co...
# ✅ Success! Extracted 179 words
#
# [12/20] Scraping: Petrol bunk owner hacked to death near Koovathur...
# URL: https://www.thehindu.com/news/cities/chennai/petrol-bunk-own...
# ✅ Success! Extracted 211 words
#
# [13/20] Scraping: Man held for inappropriate behaviour on MRTS Train...
# URL: https://www.thehindu.com/news/cities/chennai/man-held-for-in...
# ✅ Success! Extracted 152 words
#
# [14/20] Scraping: Protesting attack on shopkeeper, shops in Melur do...
# URL: https://www.thehindu.com/news/cities/Madurai/protesting-atta...
# ✅ Success! Extracted 199 words
#
# [15/20] Scraping: TNGDA stage protest demanding action against DD He...
# URL: https://www.thehindu.com/news/cities/Madurai/tngda-stage-pro...
# ✅ Success! Extracted 223 words
#
# [16/20] Scraping: EPS saying AIADMK will have majority win shows par...
# URL: https://www.thehindu.com/news/cities/Madurai/eps-saying-aiad...
# ✅ Success! Extracted 462 words
#
# [17/20] Scraping: Parents seek transport facility for students of Ko...
# URL: https://www.thehindu.com/news/cities/Madurai/parents-seek-tr...
# ✅ Success! Extracted 233 words
#
# [18/20] Scraping: Woman found dead in Valandur...
# URL: https://www.thehindu.com/news/cities/Madurai/woman-found-dea...
# ✅ Success! Extracted 204 words
#
# [19/20] Scraping: Special train service between Tirunelveli and Tiru...
# URL: https://www.thehindu.com/news/cities/Madurai/special-train-s...
# ✅ Success! Extracted 178 words
#
# [20/20] Scraping: Parents protest suspecting foul play in 7-year-old...
# URL: https://www.thehindu.com/news/cities/Madurai/parents-protest...
# ✅ Success! Extracted 135 words
#
# ...
# ✅ Success! Extracted 192 words
#
# [13/20] Scraping: Stalin inaugurates urban and primary health centre...
# URL: https://www.thehindu.com/news/cities/Madurai/stalin-inaugura...
# ✅ Success! Extracted 226 words
#
# [14/20] Scraping: T.N. will have coalition government in 2026 if NDA...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tn-will-ha...
# ✅ Success! Extracted 285 words
#
# [15/20] Scraping: T.N. trains college teachers to set question paper...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tn-trains-...
# ✅ Success! Extracted 541 words
#
# [16/20] Scraping: Sarasvati Mahal Library in Thanjavur to undergo ma...
# URL: https://www.thehindu.com/news/national/tamil-nadu/sarasvati-...
# ✅ Success! Extracted 457 words
#
# [17/20] Scraping: Vasan accuses T.N. government of failing to curb i...
# URL: https://www.thehindu.com/news/national/tamil-nadu/vasan-accu...
# ✅ Success! Extracted 148 words
#
# [18/20] Scraping: Man chased, hacked to death by armed gang in Sivag...
# URL: https://www.thehindu.com/news/national/tamil-nadu/man-chased...
# ✅ Success! Extracted 184 words
#
# [19/20] Scraping: T.N. CM Stalin condoles passing of Tamil scholar S...
# URL: https://www.thehindu.com/news/national/tamil-nadu/tn-cm-stal...
# ✅ Success! Extracted 254 words
#
# [20/20] Scraping: Construction of ₹77-crore Chennai Corporation Coun...
# URL: https://www.thehindu.com/news/cities/chennai/construction-of...
# ✅ Success! Extracted 425 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Additional Sub-Treasury officer held on bribery ch...
# ✅ Updated: Online fast-track beginner’s Japanese course to st...
# ✅ Updated: Arunthathiyar candidates can compete in SC general...
# ✅ Updated: ‘108% rise in taxpayers in the Salem GST Commissio...
# ✅ Updated: Residents say poorly designed marriage halls in Ch...
# ✅ Updated: Poaching bid in Coimbatore Forest Division hints a...
# ✅ Updated: River cleaning work at a cost of ₹25 lakh launched...
# ✅ Updated: Vaigai dam water reaches Ramanathapuram Big Tank...
# ✅ Updated: Minister reviews preparatory measures at Tiruchend...
# ✅ Updated: Three temporary bus stands and 600 special buses a...
# ✅ Updated: 25 sovereigns of gold, ₹75,000 stolen from locked ...
# ✅ Updated: Apartments under construction at Reddiyarpatti to ...
# ✅ Updated: Stalin inaugurates urban and primary health centre...
# ✅ Updated: T.N. will have coalition government in 2026 if NDA...
# ✅ Updated: T.N. trains college teachers to set question paper...
# ✅ Updated: Sarasvati Mahal Library in Thanjavur to undergo ma...
# ✅ Updated: Vasan accuses T.N. government of failing to curb i...
# ✅ Updated: Man chased, hacked to death by armed gang in Sivag...
# ✅ Updated: T.N. CM Stalin condoles passing of Tamil scholar S...
# ✅ Updated: Construction of ₹77-crore Chennai Corporation Coun...
#
# 🔄 Processing batch 21...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Inside the daily life of a Chennai street vendor w...
# URL: https://www.thehindu.com/news/cities/chennai/inside-the-dail...
# ✅ Success! Extracted 487 words
#
# [2/20] Scraping: Webinar on ‘Vitamin D Deficiency: Myths vs Reality...
# URL: https://www.thehindu.com/news/national/tamil-nadu/webinar-on...
# ✅ Success! Extracted 189 words
#
# [3/20] Scraping: Commuters flag difficulties in using credit cards ...
# URL: https://www.thehindu.com/news/cities/chennai/commuters-flag-...
# ✅ Success! Extracted 382 words
#
# [4/20] Scraping: VCK and Congress MPs question TNCC president’s dec...
# URL: https://www.thehindu.com/news/national/tamil-nadu/vck-and-co...
# ✅ Success! Extracted 472 words
#
# [5/20] Scraping: Anbumani urges Speaker to remove Arul as party’s w...
# URL: https://www.thehindu.com/news/national/tamil-nadu/anbumani-u...
# ✅ Success! Extracted 86 words
#
# [6/20] Scraping: Three, including husband, arrested for murder of V...
# URL: https://www.thehindu.com/news/cities/chennai/3-including-hus...
# ✅ Success! Extracted 255 words
#
# [7/20] Scraping: International Toilet Festival 3.0 | Greater Chenna...
# URL: https://www.thehindu.com/news/cities/chennai/international-t...
# ✅ Success! Extracted 157 words
#
# [8/20] Scraping: Palaniswami pulls up govt. for reported move to re...
# URL: https://www.thehindu.com/news/national/tamil-nadu/palaniswam...
# ✅ Success! Extracted 224 words
#
# [9/20] Scraping: Two surrender in court in connection with murder o...
# URL: https://www.thehindu.com/news/cities/Madurai/two-surrender-i...
# ✅ Success! Extracted 114 words
#
# [10/20] Scraping: Man, his second wife arrested for abetment after d...
# URL: https://www.thehindu.com/news/cities/chennai/man-his-second-...
# ✅ Success! Extracted 188 words
#
# [11/20] Scraping: Installation of street lights, sewage treatment, p...
# URL: https://www.thehindu.com/news/cities/Madurai/installation-of...
# ✅ Success! Extracted 305 words
#
# [12/20] Scraping: AIIMS medical college will start functioning on Ma...
# URL: https://www.thehindu.com/news/cities/Madurai/aiims-medical-c...
# ✅ Success! Extracted 175 words
#
# [13/20] Scraping: Constable placed under suspension for attacking di...
# URL: https://www.thehindu.com/news/cities/Madurai/constable-place...
# ✅ Success! Extracted 124 words
#
# [14/20] Scraping: Flash strike by loco pilots detains express train ...
# URL: https://www.thehindu.com/news/cities/Madurai/flash-strike-by...
# ✅ Success! Extracted 168 words
#
# [15/20] Scraping: Renovated Akshaya School for Special Children inau...
# URL: https://www.thehindu.com/news/cities/Madurai/renovated-aksha...
# ✅ Success! Extracted 314 words
#
# [16/20] Scraping: Video emerges of youth being assaulted inside poli...
# URL: https://www.thehindu.com/news/national/tamil-nadu/video-emer...
# ✅ Success! Extracted 225 words
#
# [17/20] Scraping: Industrial electricity consumers in Tamil Nadu dem...
# URL: https://www.thehindu.com/news/cities/Coimbatore/industrial-e...
# ✅ Success! Extracted 332 words
#
# [18/20] Scraping: Four fishermen rescued by Sri Lankan Navy return h...
# URL: https://www.thehindu.com/news/cities/Madurai/four-fishermen-...
# ✅ Success! Extracted 131 words
#
# [19/20] Scraping: A juvenile girl is the third accused in the murder...
# URL: https://www.thehindu.com/news/cities/Coimbatore/a-juvenile-g...
# ✅ Success! Extracted 317 words
#
# [20/20] Scraping: Coimbatore Master Plan envisages outer ring road, ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/coimbatore-m...
# ✅ Success! Extracted 370 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Inside the daily life of a Chennai street vendor w...
# ✅ Updated: Webinar on ‘Vitamin D Deficiency: Myths vs Reality...
# ✅ Updated: Commuters flag difficulties in using credit cards ...
# ✅ Updated: VCK and Congress MPs question TNCC president’s dec...
# ✅ Updated: Anbumani urges Speaker to remove Arul as party’s w...
# ✅ Updated: Three, including husband, arrested for murder of V...
# ✅ Updated: International Toilet Festival 3.0 | Greater Chenna...
# ✅ Updated: Palaniswami pulls up govt. for reported move to re...
# ✅ Updated: Two surrender in court in connection with murder o...
# ✅ Updated: Man, his second wife arrested for abetment after d...
# ✅ Updated: Installation of street lights, sewage treatment, p...
# ✅ Updated: AIIMS medical college will start functioning on Ma...
# ✅ Updated: Constable placed under suspension for attacking di...
# ✅ Updated: Flash strike by loco pilots detains express train ...
# ✅ Updated: Renovated Akshaya School for Special Children inau...
# ✅ Updated: Video emerges of youth being assaulted inside poli...
# ✅ Updated: Industrial electricity consumers in Tamil Nadu dem...
# ✅ Updated: Four fishermen rescued by Sri Lankan Navy return h...
# ✅ Updated: A juvenile girl is the third accused in the murder...
# ✅ Updated: Coimbatore Master Plan envisages outer ring road, ...
#
# 🔄 Processing batch 22...
# 🚀 Starting batch scraping: 20 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/20] Scraping: Custodial death victims’ kin should be given ₹1-cr...
# URL: https://www.thehindu.com/news/cities/Madurai/custodial-death...
# ✅ Success! Extracted 360 words
#
# [2/20] Scraping: Principal Chief Safety Officer, Southern Railway, ...
# URL: https://www.thehindu.com/news/cities/Madurai/principal-chief...
# ✅ Success! Extracted 199 words
#
# [3/20] Scraping: Ensure illegal groundwater extraction for commerci...
# URL: https://www.thehindu.com/news/cities/Madurai/ensure-illegal-...
# ✅ Success! Extracted 314 words
#
# [4/20] Scraping: 6,000 police personnel deployed and advance survei...
# URL: https://www.thehindu.com/news/cities/Madurai/6000-police-per...
# ✅ Success! Extracted 265 words
#
# [5/20] Scraping: Government school teacher in Nilgiris arrested und...
# URL: https://www.thehindu.com/news/cities/Coimbatore/government-s...
# ✅ Success! Extracted 223 words
#
# [6/20] Scraping: School near Coimbatore gets hoax bomb threat...
# URL: https://www.thehindu.com/news/cities/Coimbatore/school-near-...
# ✅ Success! Extracted 117 words
#
# [7/20] Scraping: Union Coal Minister inaugurates Neyveli Book Fair...
# URL: https://www.thehindu.com/news/national/tamil-nadu/union-coal...
# ✅ Success! Extracted 183 words
#
# [8/20] Scraping: Wild elephant damages house in Coimbatore; eats ca...
# URL: https://www.thehindu.com/news/cities/Coimbatore/wild-elephan...
# ✅ Success! Extracted 211 words
#
# [9/20] Scraping: Woman from Neelankarai held for cheating people wi...
# URL: https://www.thehindu.com/news/cities/chennai/woman-from-neel...
# ✅ Success! Extracted 213 words
#
# [10/20] Scraping: Fishermen reiterate opposition to deep-sea hydroca...
# URL: https://www.thehindu.com/news/cities/Madurai/fishermen-reite...
# ✅ Success! Extracted 315 words
#
# [11/20] Scraping: Special camp to enlighten public on installing sol...
# URL: https://www.thehindu.com/news/cities/Madurai/special-camp-to...
# ✅ Success! Extracted 142 words
#
# [12/20] Scraping: Local holiday declared on July 7 in Thoothukudi...
# URL: https://www.thehindu.com/news/cities/Madurai/local-holiday-d...
# ✅ Success! Extracted 85 words
#
# [13/20] Scraping: Pappapatti govt. elementary school students boycot...
# URL: https://www.thehindu.com/news/cities/Madurai/pappapatti-govt...
# ✅ Success! Extracted 203 words
#
# [14/20] Scraping: North Chennai EPFO gives pension payment orders to...
# URL: https://www.thehindu.com/news/cities/chennai/north-chennai-e...
# ✅ Success! Extracted 99 words
#
# [15/20] Scraping: Innovation Voucher Programme rolled out in NIFT-TE...
# URL: https://www.thehindu.com/news/cities/Coimbatore/innovation-v...
# ✅ Success! Extracted 328 words
#
# [16/20] Scraping: IUML leader Khader Mohideen chosen for Thagaisal T...
# URL: https://www.thehindu.com/news/national/tamil-nadu/iuml-leade...
# ✅ Success! Extracted 183 words
#
# [17/20] Scraping: Infant’s thumb severed in
# GH: HC directs State to...
# URL: https://www.thehindu.com/news/cities/Madurai/madras-high-cou...
# ✅ Success! Extracted 287 words
#
# [18/20] Scraping: Medical experts call for increased vaccination to ...
# URL: https://www.thehindu.com/news/cities/Coimbatore/medical-expe...
# ✅ Success! Extracted 331 words
#
# [19/20] Scraping: E-buses packed with features for safety, passenger...
# URL: https://www.thehindu.com/news/cities/chennai/e-buses-hit-the...
# ✅ Success! Extracted 516 words
#
# [20/20] Scraping: AIADMK accuses Tirunelveli Corporation of rampant ...
# URL: https://www.thehindu.com/news/cities/Madurai/aiadmk-accuses-...
# ✅ Success! Extracted 481 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Custodial death victims’ kin should be given ₹1-cr...
# ✅ Updated: Principal Chief Safety Officer, Southern Railway, ...
# ✅ Updated: Ensure illegal groundwater extraction for commerci...
# ✅ Updated: 6,000 police personnel deployed and advance survei...
# ✅ Updated: Government school teacher in Nilgiris arrested und...
# ✅ Updated: School near Coimbatore gets hoax bomb threat...
# ✅ Updated: Union Coal Minister inaugurates Neyveli Book Fair...
# ✅ Updated: Wild elephant damages house in Coimbatore; eats ca...
# ✅ Updated: Woman from Neelankarai held for cheating people wi...
# ✅ Updated: Fishermen reiterate opposition to deep-sea hydroca...
# ✅ Updated: Special camp to enlighten public on installing sol...
# ✅ Updated: Local holiday declared on July 7 in Thoothukudi...
# ✅ Updated: Pappapatti govt. elementary school students boycot...
# ✅ Updated: North Chennai EPFO gives pension payment orders to...
# ✅ Updated: Innovation Voucher Programme rolled out in NIFT-TE...
# ✅ Updated: IUML leader Khader Mohideen chosen for Thagaisal T...
# ✅ Updated: Infant’s thumb severed in
# GH: HC directs State to...
# ✅ Updated: Medical experts call for increased vaccination to ...
# ✅ Updated: E-buses packed with features for safety, passenger...
# ✅ Updated: AIADMK accuses Tirunelveli Corporation of rampant ...
#
# 🔄 Processing batch 23...
# 🚀 Starting batch scraping: 12 articles
# ⏱️  Rate limit: 2.5s between requests
#
# ============================================================
#
# [1/12] Scraping: Chief Minister inaugurates new accommodation facil...
# URL: https://www.thehindu.com/news/cities/Madurai/chief-minister-...
# ✅ Success! Extracted 211 words
#
# [2/12] Scraping: Drones used to drive elephants back into forest...
# URL: https://www.thehindu.com/news/cities/Coimbatore/drones-used-...
# ✅ Success! Extracted 83 words
#
# [3/12] Scraping: Animal disease investigation unit inaugurated at T...
# URL: https://www.thehindu.com/news/cities/Madurai/animal-disease-...
# ✅ Success! Extracted 236 words
#
# [4/12] Scraping: Inhabitants of Sri Lankan Tamil camp at Moongiloor...
# URL: https://www.thehindu.com/news/cities/Madurai/inhabitants-of-...
# ✅ Success! Extracted 352 words
#
# [5/12] Scraping: Centre gives permission to paddy and banana farmer...
# URL: https://www.thehindu.com/news/cities/Madurai/centre-gives-pe...
# ✅ Success! Extracted 416 words
#
# [6/12] Scraping: Hogenakkal’s water level rises to 43,000 cusecs fr...
# URL: https://www.thehindu.com/news/cities/Coimbatore/hogenakkals-...
# ✅ Success! Extracted 94 words
#
# [7/12] Scraping: Salem Railway Division collects ₹6.18 crore as fin...
# URL: https://www.thehindu.com/news/cities/Coimbatore/salem-railwa...
# ✅ Success! Extracted 248 words
#
# [8/12] Scraping: Hoax bomb threat received at Erode Collectorate...
# URL: https://www.thehindu.com/news/cities/Coimbatore/hoax-bomb-th...
# ✅ Success! Extracted 153 words
#
# [9/12] Scraping: Partial cancellation of train services between Ero...
# URL: https://www.thehindu.com/news/cities/Coimbatore/partial-canc...
# ✅ Success! Extracted 131 words
#
# [10/12] Scraping: School Education Department to step up competitive...
# URL: https://www.thehindu.com/news/cities/Coimbatore/school-educa...
# ✅ Success! Extracted 368 words
#
# [11/12] Scraping: Greater Chennai Corporation begins training newly-...
# URL: https://www.thehindu.com/news/cities/chennai/greater-chennai...
# ✅ Success! Extracted 158 words
#
# [12/12] Scraping: Stalin inaugurates integrated agriculture extensio...
# URL: https://www.thehindu.com/news/cities/Madurai/stalin-inaugura...
# ✅ Success! Extracted 250 words
#
# ============================================================
# ✅ Batch scraping complete!
# 🔄 Updating database...
#
# ✅ Updated: Chief Minister inaugurates new accommodation facil...
# ✅ Updated: Drones used to drive elephants back into forest...
# ✅ Updated: Animal disease investigation unit inaugurated at T...
# ✅ Updated: Inhabitants of Sri Lankan Tamil camp at Moongiloor...
# ✅ Updated: Centre gives permission to paddy and banana farmer...
# ✅ Updated: Hogenakkal’s water level rises to 43,000 cusecs fr...
# ✅ Updated: Salem Railway Division collects ₹6.18 crore as fin...
# ✅ Updated: Hoax bomb threat received at Erode Collectorate...
# ✅ Updated: Partial cancellation of train services between Ero...
# ✅ Updated: School Education Department to step up competitive...
# ✅ Updated: Greater Chennai Corporation begins training newly-...
# ✅ Updated: Stalin inaugurates integrated agriculture extensio...
#
# ✅ All articles processed!

# %% [markdown]
# ## Final Report & Next Steps

# %%
# Generate final report
print("="*60)
print("📋 FINAL SCRAPING REPORT")
print("="*60)
print(f"\nTest Batch Results:")
print(f"  Attempted: {len(test_batch)}")
print(f"  Successful: {success_count} ({success_rate:.1f}%)")
print(f"  Failed: {failure_count}")
print(f"  Avg Word Count: {successful_df['word_count'].mean():.0f} words")

print(f"\nDatabase Status:")
print(f"  Total articles in DB: 150")
print(f"  With full content: {with_content.count}")
print(f"  Still need scraping: {remaining.count}")

print(f"\nNext Steps:")
if success_rate > 70:
    print("  ✅ Success rate is good! Process remaining articles.")
elif success_rate > 50:
    print("  ⚠️  Success rate is moderate. Review failed extractions.")
    print("  ⚠️  Consider adjusting extraction parameters")
else:
    print("  ❌ Success rate is low. May need custom scraper.")
    print("  ❌ Review The Hindu's HTML structure manually")

print("\n" + "="*60)
# Out:
# ============================================================
# 📋 FINAL SCRAPING REPORT
# ============================================================
#
# Test Batch Results:
#   Attempted: 10
#   Successful: 10 (100.0%)
#   Failed: 0
#   Avg Word Count: 226 words
#
# Database Status:
#   Total articles in DB: 150
#   With full content: 2292
#   Still need scraping: 452
#
# Next Steps:
#   ✅ Success rate is good! Process remaining articles.
#
# ============================================================
